# %%
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas-datareader) (5.2.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas-datareader) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
import pandas_datareader.data as web
start='2015-01-01'
end='2023-01-01'

df=web.DataReader('JPM','stooq',start,end)
df.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2022-12-30  132.81  134.33  132.44  134.10  9292519.0
# 2022-12-29  132.93  133.27  132.31  133.22  6585228.0
# 2022-12-28  131.85  133.41  131.01  132.46  8827738.0
# 2022-12-27  131.57  132.22  130.55  131.74  5410991.0
# 2022-12-23  130.58  131.44  129.64  131.28  5091905.0

# %%
df.tail()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2015-01-08  48.2753  49.0259  48.2753  48.6122  2.107993e+07
# 2015-01-07  48.2143  48.2143  47.2329  47.5512  2.961840e+07
# 2015-01-06  48.8155  48.9040  46.9735  47.4804  3.611625e+07
# 2015-01-05  49.9581  50.1369  48.4845  48.7429  2.496834e+07
# 2015-01-02  50.4111  50.6861  49.9670  50.3059  1.564852e+07

# %%
#  Date becomes column and are removable.
df=df.reset_index()
df.head()
# Out:
#         Date    Open    High     Low   Close     Volume
# 0 2022-12-30  132.81  134.33  132.44  134.10  9292519.0
# 1 2022-12-29  132.93  133.27  132.31  133.22  6585228.0
# 2 2022-12-28  131.85  133.41  131.01  132.46  8827738.0
# 3 2022-12-27  131.57  132.22  130.55  131.74  5410991.0
# 4 2022-12-23  130.58  131.44  129.64  131.28  5091905.0

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close     Volume
# 0 2022-12-30  132.81  134.33  132.44  134.10  9292519.0
# 1 2022-12-29  132.93  133.27  132.31  133.22  6585228.0
# 2 2022-12-28  131.85  133.41  131.01  132.46  8827738.0
# 3 2022-12-27  131.57  132.22  130.55  131.74  5410991.0
# 4 2022-12-23  130.58  131.44  129.64  131.28  5091905.0

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig=plt.figure(figsize=(10,6))
fig.patch.set_facecolor('#42A5F5')

ax=plt.axes()
ax.set_facecolor('#C7E1F4')

plt.plot(df.Close, '#FF8F00', label='Closing Price')

plt.legend()
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.xticks(rotation=45)

plt.grid(True,linestyle='--',color='#BDBDBD')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#            Date      Open      High       Low     Close        Volume
# 0    2022-12-30  132.8100  134.3300  132.4400  134.1000  9.292519e+06
# 1    2022-12-29  132.9300  133.2700  132.3100  133.2200  6.585228e+06
# 2    2022-12-28  131.8500  133.4100  131.0100  132.4600  8.827738e+06
# 3    2022-12-27  131.5700  132.2200  130.5500  131.7400  5.410991e+06
# 4    2022-12-23  130.5800  131.4400  129.6400  131.2800  5.091905e+06
# ...         ...       ...       ...       ...       ...           ...
# 2009 2015-01-08   48.2753   49.0259   48.2753   48.6122  2.107993e+07
# 2010 2015-01-07   48.2143   48.2143   47.2329   47.5512  2.961840e+07
# 2011 2015-01-06   48.8155   48.9040   46.9735   47.4804  3.611625e+07
# 2012 2015-01-05   49.9581   50.1369   48.4845   48.7429  2.496834e+07
# 2013 2015-01-02   50.4111   50.6861   49.9670   50.3059  1.564852e+07
#
# [2014 rows x 6 columns]

# %%
# ma100 is created for finding the mean of the 100 values and displaying them.
# for that rolling() function is used.

ma100=df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2009    49.436667
# 2010    49.377171
# 2011    49.316465
# 2012    49.270830
# 2013    49.237437
# Name: Close, Length: 2014, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
fig.patch.set_facecolor('#42A5F5')

ax=plt.axes()
ax.set_facecolor('#C7E1F4')

plt.grid(True,linestyle='--',color='#BDBDBD')
plt.tight_layout()

plt.plot(df.Close, '#FF8F00', label='Openign Price')
plt.plot(ma100,'g--',label='Mean (100 val)') # this is the mean of 100 values

plt.legend()
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.show()

# %%
ma200=df.Close.rolling(200).mean()
ma50=df.Close.rolling(50).mean()
ma75=df.Close.rolling(75).mean()
ma150=df.Close.rolling(150).mean()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

ma100=df.Close.rolling(100).mean()
ma100

fig=plt.figure(figsize=(12,6))
fig.patch.set_facecolor('#A59DDF')

ax=plt.axes()
ax.set_facecolor('#211970')

plt.grid(True,linestyle='--',color='#626784')
plt.xticks(rotation=45)

plt.plot(df.Close,'#A720C4',label='Opening Price')
plt.plot(ma50,'y',label='Mean (50 val)')
plt.plot(ma75,'b',label='Mean (75 val)')
plt.plot(ma100,'g',label='Mean (100 val)') # this is the mean of 100 values
plt.plot(ma200,'r',label='Mean (200 val)') # this is the mean of 200 values

plt.legend()
plt.xlabel('Date')
plt.ylabel('Opening Price (USD)')
# Out:
# Text(0, 0.5, 'Opening Price (USD)')

# %%
df.shape
# Out:
# (2014, 6)

# %%
# splitting the data into training and testing
import pandas as pd

data_training = pd.DataFrame(df[['Close','Date']][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df[['Close','Date']][int(len(df)*0.70):int(len(df))])

print("Used data for training: ", data_training.shape)
print("Used data for testing: ", data_testing.shape)
# Out:
# Used data for training:  (1409, 2)
# Used data for testing:  (605, 2)

# %%
data_training.head()
# Out:
#     Close       Date
# 0  134.10 2022-12-30
# 1  133.22 2022-12-29
# 2  132.46 2022-12-28
# 3  131.74 2022-12-27
# 4  131.28 2022-12-23

# %%
data_testing.head()
# Out:
#         Close       Date
# 1409  73.0102 2017-05-26
# 1410  73.0024 2017-05-25
# 1411  73.3138 2017-05-24
# 1412  73.3520 2017-05-23
# 1413  72.4482 2017-05-22

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

data_training_array = scaler.fit_transform(data_training[['Close']])
data_training_array
# Out:
# array([[0.66315807],
#        [0.65401605],
#        [0.64612067],
#        ...,
#        [0.00807407],
#        [0.        ],
#        [0.01556429]])

# %%
import numpy as np

# The data is dependant on the previous result. (ma100) and (ma200)
# So, to calculate the next day value we train the following array.
# 100 days are x_train and 101 day is y_train and it goes on changing.

x_train = []
y_train = []


for i in range(100,data_training_array.shape[0]):
  x_train.append(data_training_array[i-100: i])
  y_train.append(data_training_array[i, 0])


x_train

# Now, converting x_train into numpy value, so that it can be provided to LSTM.
x_train,y_train = np.array(x_train), np.array(y_train)

# %%
# !pip install tensorflow
# !pip install tensorflow-addons==0.17.1

# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (20.9)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from packaging->tensorflow-intel==2.18.0->tensorflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons==0.17.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons==0.17.1
# Requirement already satisfied: tensorflow in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (20.9)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from packaging->tensorflow-intel==2.18.0->tensorflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/tensorflow-addons/
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons

# %%
import tensorflow as tf

# Use the recommended import path for LSTM
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
# Use the recommended import path for LSTM
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Orthogonal

# ... rest of your code ...
import tensorflow as tf


model = tf.keras.Sequential()
model.add(LSTM(units=50,
               activation ='relu',
               return_sequences = True,
               input_shape=(x_train.shape[1],1),
                recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.2))


# Second Layer
model.add(LSTM(units=60,
               activation ='relu',
               return_sequences = True,
               recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.3))



model.add(LSTM(units=80,
               activation ='relu',
               return_sequences = True,
               recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.4))



model.add(LSTM(units=120,
               activation ='relu',
               recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.5))



# Dense Layer - to connect all the layers
# model.add(Dense(units=1))
model.add(tf.keras.layers.Dense(units=1, kernel_initializer=Orthogonal(gain=1.0, seed=None)))

# Set Optimizer
opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
# Out:
# c:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# !pip install tensorflow-addons==0.17.1

# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-addons
# Out:
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons==0.17.1 (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons==0.17.1
# Requirement already satisfied: tensorflow in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (20.9)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (69.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from packaging->tensorflow-intel==2.18.0->tensorflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sinha\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorboard (C:\Users\sinha\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons

# %%
# Try importing AbstractRNNCell from tensorflow.python.keras.layers instead

from tensorflow.python.keras.layers import AbstractRNNCell

# Remove the incorrect import and keep the original correct one
# from tensorflow.python.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization # This line was already in a previous cell, keep it
from tensorflow.python.keras.callbacks import TensorBoard
from tensorflow.python.keras.callbacks import ModelCheckpoint

from tensorflow.python.keras.initializers import Orthogonal
from tensorflow.python.keras.metrics import MeanSquaredError, MeanAbsoluteError

model.compile(optimizer=opt,
              loss='mean_squared_error',  # Retain MSE for regression
              metrics=['accuracy',  # Include accuracy for reference (optional)
                       MeanSquaredError(),
                       MeanAbsoluteError()])

model.fit(x_train,y_train,epochs=300)
# Out:
# Epoch 1/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 34s 256ms/step - accuracy: 4.6530e-04 - loss: 0.1178 - mean_absolute_error: 0.3258 - mean_squared_error: 0.1661
# Epoch 2/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 1.4862e-04 - loss: 0.0181 - mean_absolute_error: 0.1605 - mean_squared_error: 0.0526
# Epoch 3/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.0015 - loss: 0.0129 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0359
# Epoch 4/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 9.8806e-04 - loss: 0.0152 - mean_absolute_error: 0.1164 - mean_squared_error: 0.0292
# Epoch 5/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 0.0039 - loss: 0.0112 - mean_absolute_error: 0.1075 - mean_squared_error: 0.0251
# Epoch 6/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 0.0019 - loss: 0.0098 - mean_absolute_error: 0.1009 - mean_squared_error: 0.0223
# Epoch 7/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 0.0039 - loss: 0.0094 - mean_absolute_error: 0.0964 - mean_squared_error: 0.0203
# Epoch 8/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 251ms/step - accuracy: 0.0011 - loss: 0.0092 - mean_absolute_error: 0.0926 - mean_squared_error: 0.0188
# Epoch 9/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 237ms/step - accuracy: 9.5617e-04 - loss: 0.0103 - mean_absolute_error: 0.0899 - mean_squared_error: 0.0176
# Epoch 10/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 0.0012 - loss: 0.0081 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0167
# Epoch 11/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 231ms/step - accuracy: 0.0012 - loss: 0.0095 - mean_absolute_error: 0.0857 - mean_squared_error: 0.0159
# Epoch 12/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 243ms/step - accuracy: 7.9504e-04 - loss: 0.0080 - mean_absolute_error: 0.0841 - mean_squared_error: 0.0153
# Epoch 13/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 249ms/step - accuracy: 0.0015 - loss: 0.0090 - mean_absolute_error: 0.0828 - mean_squared_error: 0.0148
# Epoch 14/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 8.0349e-04 - loss: 0.0088 - mean_absolute_error: 0.0817 - mean_squared_error: 0.0143
# Epoch 15/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 235ms/step - accuracy: 5.9791e-04 - loss: 0.0077 - mean_absolute_error: 0.0805 - mean_squared_error: 0.0139
# Epoch 16/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 234ms/step - accuracy: 6.8505e-04 - loss: 0.0076 - mean_absolute_error: 0.0793 - mean_squared_error: 0.0135
# Epoch 17/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 7.3251e-04 - loss: 0.0069 - mean_absolute_error: 0.0783 - mean_squared_error: 0.0131
# Epoch 18/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0015 - loss: 0.0067 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0128
# Epoch 19/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 0.0012 - loss: 0.0072 - mean_absolute_error: 0.0765 - mean_squared_error: 0.0125
# Epoch 20/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 6.3368e-04 - loss: 0.0060 - mean_absolute_error: 0.0757 - mean_squared_error: 0.0122
# Epoch 21/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 7.0814e-04 - loss: 0.0059 - mean_absolute_error: 0.0748 - mean_squared_error: 0.0119
# Epoch 22/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 246ms/step - accuracy: 6.9388e-04 - loss: 0.0065 - mean_absolute_error: 0.0741 - mean_squared_error: 0.0117
# Epoch 23/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 0.0014 - loss: 0.0062 - mean_absolute_error: 0.0732 - mean_squared_error: 0.0114
# Epoch 24/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.0024 - loss: 0.0056 - mean_absolute_error: 0.0724 - mean_squared_error: 0.0111
# Epoch 25/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.0013 - loss: 0.0054 - mean_absolute_error: 0.0716 - mean_squared_error: 0.0109
# Epoch 26/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 0.0022 - loss: 0.0059 - mean_absolute_error: 0.0709 - mean_squared_error: 0.0107
# Epoch 27/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 0.0022 - loss: 0.0052 - mean_absolute_error: 0.0702 - mean_squared_error: 0.0105
# Epoch 28/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 243ms/step - accuracy: 0.0014 - loss: 0.0055 - mean_absolute_error: 0.0696 - mean_squared_error: 0.0103
# Epoch 29/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.0018 - loss: 0.0050 - mean_absolute_error: 0.0691 - mean_squared_error: 0.0101
# Epoch 30/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 260ms/step - accuracy: 0.0025 - loss: 0.0055 - mean_absolute_error: 0.0685 - mean_squared_error: 0.0100
# Epoch 31/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 243ms/step - accuracy: 5.9700e-04 - loss: 0.0046 - mean_absolute_error: 0.0679 - mean_squared_error: 0.0098
# Epoch 32/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 0.0016 - loss: 0.0051 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0097
# Epoch 33/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 0.0023 - loss: 0.0052 - mean_absolute_error: 0.0669 - mean_squared_error: 0.0095
# Epoch 34/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 0.0018 - loss: 0.0049 - mean_absolute_error: 0.0665 - mean_squared_error: 0.0094
# Epoch 35/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 5.2449e-04 - loss: 0.0047 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0093
# Epoch 36/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - accuracy: 0.0023 - loss: 0.0051 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0091
# Epoch 37/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 0.0032 - loss: 0.0048 - mean_absolute_error: 0.0651 - mean_squared_error: 0.0090
# Epoch 38/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 0.0038 - loss: 0.0042 - mean_absolute_error: 0.0647 - mean_squared_error: 0.0089
# Epoch 39/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 3.7937e-04 - loss: 0.0047 - mean_absolute_error: 0.0642 - mean_squared_error: 0.0088
# Epoch 40/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 3.7903e-04 - loss: 0.0046 - mean_absolute_error: 0.0638 - mean_squared_error: 0.0087
# Epoch 41/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 0.0019 - loss: 0.0042 - mean_absolute_error: 0.0634 - mean_squared_error: 0.0086
# Epoch 42/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.0019 - loss: 0.0046 - mean_absolute_error: 0.0630 - mean_squared_error: 0.0085
# Epoch 43/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - accuracy: 0.0026 - loss: 0.0046 - mean_absolute_error: 0.0626 - mean_squared_error: 0.0084
# Epoch 44/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 4.7537e-04 - loss: 0.0043 - mean_absolute_error: 0.0623 - mean_squared_error: 0.0083
# Epoch 45/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 6.9703e-04 - loss: 0.0049 - mean_absolute_error: 0.0619 - mean_squared_error: 0.0082
# Epoch 46/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0017 - loss: 0.0037 - mean_absolute_error: 0.0616 - mean_squared_error: 0.0081
# Epoch 47/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 257ms/step - accuracy: 0.0019 - loss: 0.0045 - mean_absolute_error: 0.0613 - mean_squared_error: 0.0080
# Epoch 48/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 0.0017 - loss: 0.0044 - mean_absolute_error: 0.0610 - mean_squared_error: 0.0079
# Epoch 49/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 5.4774e-04 - loss: 0.0038 - mean_absolute_error: 0.0607 - mean_squared_error: 0.0079
# Epoch 50/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 243ms/step - accuracy: 8.7795e-04 - loss: 0.0040 - mean_absolute_error: 0.0604 - mean_squared_error: 0.0078
# Epoch 51/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 243ms/step - accuracy: 0.0036 - loss: 0.0045 - mean_absolute_error: 0.0601 - mean_squared_error: 0.0077
# Epoch 52/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 8.9145e-04 - loss: 0.0037 - mean_absolute_error: 0.0598 - mean_squared_error: 0.0076
# Epoch 53/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 0.0014 - loss: 0.0038 - mean_absolute_error: 0.0595 - mean_squared_error: 0.0076
# Epoch 54/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 192ms/step - accuracy: 7.9803e-04 - loss: 0.0034 - mean_absolute_error: 0.0593 - mean_squared_error: 0.0075
# Epoch 55/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - accuracy: 0.0031 - loss: 0.0037 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0074
# Epoch 56/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.0016 - loss: 0.0040 - mean_absolute_error: 0.0587 - mean_squared_error: 0.0074
# Epoch 57/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.0039 - loss: 0.0042 - mean_absolute_error: 0.0585 - mean_squared_error: 0.0073
# Epoch 58/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 0.0017 - loss: 0.0041 - mean_absolute_error: 0.0583 - mean_squared_error: 0.0073
# Epoch 59/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.0019 - loss: 0.0037 - mean_absolute_error: 0.0581 - mean_squared_error: 0.0072
# Epoch 60/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0014 - loss: 0.0034 - mean_absolute_error: 0.0578 - mean_squared_error: 0.0071
# Epoch 61/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 254ms/step - accuracy: 6.1651e-04 - loss: 0.0040 - mean_absolute_error: 0.0576 - mean_squared_error: 0.0071
# Epoch 62/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 8.8531e-04 - loss: 0.0039 - mean_absolute_error: 0.0574 - mean_squared_error: 0.0070
# Epoch 63/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 254ms/step - accuracy: 0.0019 - loss: 0.0037 - mean_absolute_error: 0.0572 - mean_squared_error: 0.0070
# Epoch 64/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 0.0014 - loss: 0.0036 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0069
# Epoch 65/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 2.4931e-04 - loss: 0.0036 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0069
# Epoch 66/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 0.0018 - loss: 0.0035 - mean_absolute_error: 0.0565 - mean_squared_error: 0.0068
# Epoch 67/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 4.1156e-04 - loss: 0.0036 - mean_absolute_error: 0.0563 - mean_squared_error: 0.0068
# Epoch 68/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.0029 - loss: 0.0038 - mean_absolute_error: 0.0562 - mean_squared_error: 0.0067
# Epoch 69/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.0023 - loss: 0.0036 - mean_absolute_error: 0.0559 - mean_squared_error: 0.0067
# Epoch 70/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 251ms/step - accuracy: 8.6732e-04 - loss: 0.0032 - mean_absolute_error: 0.0558 - mean_squared_error: 0.0066
# Epoch 71/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 3.4622e-04 - loss: 0.0036 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0066
# Epoch 72/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 0.0023 - loss: 0.0038 - mean_absolute_error: 0.0554 - mean_squared_error: 0.0065
# Epoch 73/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 244ms/step - accuracy: 4.8006e-04 - loss: 0.0038 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0065
# Epoch 74/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 0.0012 - loss: 0.0034 - mean_absolute_error: 0.0551 - mean_squared_error: 0.0065
# Epoch 75/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 6.4191e-04 - loss: 0.0032 - mean_absolute_error: 0.0549 - mean_squared_error: 0.0064
# Epoch 76/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0011 - loss: 0.0034 - mean_absolute_error: 0.0547 - mean_squared_error: 0.0064
# Epoch 77/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0011 - loss: 0.0035 - mean_absolute_error: 0.0546 - mean_squared_error: 0.0063
# Epoch 78/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 0.0020 - loss: 0.0034 - mean_absolute_error: 0.0544 - mean_squared_error: 0.0063
# Epoch 79/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0023 - loss: 0.0032 - mean_absolute_error: 0.0543 - mean_squared_error: 0.0063
# Epoch 80/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 257ms/step - accuracy: 0.0025 - loss: 0.0033 - mean_absolute_error: 0.0541 - mean_squared_error: 0.0062
# Epoch 81/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 0.0012 - loss: 0.0034 - mean_absolute_error: 0.0540 - mean_squared_error: 0.0062
# Epoch 82/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 0.0014 - loss: 0.0034 - mean_absolute_error: 0.0538 - mean_squared_error: 0.0062
# Epoch 83/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 251ms/step - accuracy: 5.6731e-04 - loss: 0.0028 - mean_absolute_error: 0.0537 - mean_squared_error: 0.0061
# Epoch 84/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 5.2950e-04 - loss: 0.0039 - mean_absolute_error: 0.0535 - mean_squared_error: 0.0061
# Epoch 85/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0014 - loss: 0.0032 - mean_absolute_error: 0.0534 - mean_squared_error: 0.0061
# Epoch 86/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.0031 - loss: 0.0031 - mean_absolute_error: 0.0533 - mean_squared_error: 0.0060
# Epoch 87/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - accuracy: 0.0011 - loss: 0.0039 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0060
# Epoch 88/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 229ms/step - accuracy: 8.5548e-04 - loss: 0.0031 - mean_absolute_error: 0.0530 - mean_squared_error: 0.0060
# Epoch 89/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 207ms/step - accuracy: 0.0020 - loss: 0.0029 - mean_absolute_error: 0.0529 - mean_squared_error: 0.0059
# Epoch 90/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 292ms/step - accuracy: 0.0023 - loss: 0.0032 - mean_absolute_error: 0.0527 - mean_squared_error: 0.0059
# Epoch 91/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 285ms/step - accuracy: 0.0013 - loss: 0.0031 - mean_absolute_error: 0.0526 - mean_squared_error: 0.0059
# Epoch 92/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - accuracy: 4.7226e-04 - loss: 0.0031 - mean_absolute_error: 0.0525 - mean_squared_error: 0.0058
# Epoch 93/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 252ms/step - accuracy: 0.0015 - loss: 0.0033 - mean_absolute_error: 0.0524 - mean_squared_error: 0.0058
# Epoch 94/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0011 - loss: 0.0032 - mean_absolute_error: 0.0523 - mean_squared_error: 0.0058
# Epoch 95/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 285ms/step - accuracy: 0.0012 - loss: 0.0031 - mean_absolute_error: 0.0521 - mean_squared_error: 0.0058
# Epoch 96/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 0.0021 - loss: 0.0034 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0057
# Epoch 97/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.0015 - loss: 0.0030 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0057
# Epoch 98/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - accuracy: 0.0020 - loss: 0.0029 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0057
# Epoch 99/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 0.0015 - loss: 0.0031 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0057
# Epoch 100/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.0019 - loss: 0.0027 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0056
# Epoch 101/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.0019 - loss: 0.0032 - mean_absolute_error: 0.0514 - mean_squared_error: 0.0056
# Epoch 102/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 254ms/step - accuracy: 9.2845e-04 - loss: 0.0030 - mean_absolute_error: 0.0513 - mean_squared_error: 0.0056
# Epoch 103/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 251ms/step - accuracy: 9.4882e-04 - loss: 0.0027 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0055
# Epoch 104/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 0.0014 - loss: 0.0031 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0055
# Epoch 105/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.0012 - loss: 0.0031 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0055
# Epoch 106/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 0.0024 - loss: 0.0032 - mean_absolute_error: 0.0509 - mean_squared_error: 0.0055
# Epoch 107/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.0019 - loss: 0.0034 - mean_absolute_error: 0.0508 - mean_squared_error: 0.0055
# Epoch 108/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 0.0014 - loss: 0.0032 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0054
# Epoch 109/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 251ms/step - accuracy: 6.4191e-04 - loss: 0.0032 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0054
# Epoch 110/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 3.1135e-04 - loss: 0.0030 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0054
# Epoch 111/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.0024 - loss: 0.0027 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0054
# Epoch 112/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 257ms/step - accuracy: 0.0012 - loss: 0.0030 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0053
# Epoch 113/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 0.0025 - loss: 0.0029 - mean_absolute_error: 0.0503 - mean_squared_error: 0.0053
# Epoch 114/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 0.0016 - loss: 0.0032 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0053
# Epoch 115/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0017 - loss: 0.0030 - mean_absolute_error: 0.0501 - mean_squared_error: 0.0053
# Epoch 116/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 256ms/step - accuracy: 7.1561e-04 - loss: 0.0030 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0053
# Epoch 117/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - accuracy: 0.0017 - loss: 0.0028 - mean_absolute_error: 0.0499 - mean_squared_error: 0.0052
# Epoch 118/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - accuracy: 0.0027 - loss: 0.0030 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0052
# Epoch 119/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 207ms/step - accuracy: 0.0015 - loss: 0.0031 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0052
# Epoch 120/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 206ms/step - accuracy: 6.2411e-04 - loss: 0.0031 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0052
# Epoch 121/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 277ms/step - accuracy: 7.1293e-04 - loss: 0.0032 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0052
# Epoch 122/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 230ms/step - accuracy: 0.0029 - loss: 0.0030 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0052
# Epoch 123/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - accuracy: 0.0016 - loss: 0.0029 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0051
# Epoch 124/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 248ms/step - accuracy: 0.0023 - loss: 0.0033 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0051
# Epoch 125/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 254ms/step - accuracy: 7.0760e-04 - loss: 0.0027 - mean_absolute_error: 0.0493 - mean_squared_error: 0.0051
# Epoch 126/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.0032 - loss: 0.0029 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0051
# Epoch 127/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - accuracy: 0.0018 - loss: 0.0031 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0051
# Epoch 128/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 0.0025 - loss: 0.0028 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0051
# Epoch 129/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 253ms/step - accuracy: 3.3419e-04 - loss: 0.0034 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0050
# Epoch 130/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 0.0015 - loss: 0.0031 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0050
# Epoch 131/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 257ms/step - accuracy: 0.0017 - loss: 0.0027 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0050
# Epoch 132/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - accuracy: 5.7931e-04 - loss: 0.0029 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0050
# Epoch 133/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 228ms/step - accuracy: 5.4517e-04 - loss: 0.0028 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0050
# Epoch 134/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 261ms/step - accuracy: 0.0018 - loss: 0.0028 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0050
# Epoch 135/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 260ms/step - accuracy: 0.0012 - loss: 0.0031 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0049
# Epoch 136/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0020 - loss: 0.0028 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0049
# Epoch 137/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - accuracy: 0.0035 - loss: 0.0032 - mean_absolute_error: 0.0485 - mean_squared_error: 0.0049
# Epoch 138/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0018 - loss: 0.0025 - mean_absolute_error: 0.0484 - mean_squared_error: 0.0049
# Epoch 139/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 256ms/step - accuracy: 3.7903e-04 - loss: 0.0027 - mean_absolute_error: 0.0484 - mean_squared_error: 0.0049
# Epoch 140/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 256ms/step - accuracy: 8.5229e-04 - loss: 0.0027 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0049
# Epoch 141/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0010 - loss: 0.0027 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0049
# Epoch 142/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 183ms/step - accuracy: 0.0029 - loss: 0.0030 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0048
# Epoch 143/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 242ms/step - accuracy: 9.7655e-04 - loss: 0.0029 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0048
# Epoch 144/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 216ms/step - accuracy: 0.0011 - loss: 0.0028 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0048
# Epoch 145/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 223ms/step - accuracy: 0.0016 - loss: 0.0030 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0048
# Epoch 146/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 254ms/step - accuracy: 0.0014 - loss: 0.0027 - mean_absolute_error: 0.0479 - mean_squared_error: 0.0048
# Epoch 147/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 2.5973e-04 - loss: 0.0028 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0048
# Epoch 148/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - accuracy: 1.8780e-04 - loss: 0.0027 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0048
# Epoch 149/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 245ms/step - accuracy: 5.5507e-04 - loss: 0.0028 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0047
# Epoch 150/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 257ms/step - accuracy: 5.1538e-04 - loss: 0.0031 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0047
# Epoch 151/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0010 - loss: 0.0028 - mean_absolute_error: 0.0476 - mean_squared_error: 0.0047
# Epoch 152/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 255ms/step - accuracy: 0.0036 - loss: 0.0028 - mean_absolute_error: 0.0475 - mean_squared_error: 0.0047
# Epoch 153/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 260ms/step - accuracy: 0.0029 - loss: 0.0030 - mean_absolute_error: 0.0475 - mean_squared_error: 0.0047
# Epoch 154/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 267ms/step - accuracy: 0.0013 - loss: 0.0027 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0047
# Epoch 155/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.0012 - loss: 0.0027 - mean_absolute_error: 0.0473 - mean_squared_error: 0.0047
# Epoch 156/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 8.2496e-04 - loss: 0.0029 - mean_absolute_error: 0.0473 - mean_squared_error: 0.0047
# Epoch 157/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 0.0029 - loss: 0.0031 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0046
# Epoch 158/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0014 - loss: 0.0025 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0046
# Epoch 159/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - accuracy: 0.0014 - loss: 0.0024 - mean_absolute_error: 0.0471 - mean_squared_error: 0.0046
# Epoch 160/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.0026 - loss: 0.0030 - mean_absolute_error: 0.0471 - mean_squared_error: 0.0046
# Epoch 161/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 2.4931e-04 - loss: 0.0025 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0046
# Epoch 162/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 7.7496e-04 - loss: 0.0028 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0046
# Epoch 163/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 7.7966e-04 - loss: 0.0029 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0046
# Epoch 164/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 3.6077e-04 - loss: 0.0027 - mean_absolute_error: 0.0469 - mean_squared_error: 0.0046
# Epoch 165/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 0.0040 - loss: 0.0027 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0045
# Epoch 166/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 261ms/step - accuracy: 0.0017 - loss: 0.0026 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0045
# Epoch 167/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 262ms/step - accuracy: 0.0028 - loss: 0.0027 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0045
# Epoch 168/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 257ms/step - accuracy: 6.4976e-04 - loss: 0.0028 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0045
# Epoch 169/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0013 - loss: 0.0028 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0045
# Epoch 170/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 0.0020 - loss: 0.0028 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0045
# Epoch 171/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0023 - loss: 0.0029 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0045
# Epoch 172/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 260ms/step - accuracy: 0.0031 - loss: 0.0028 - mean_absolute_error: 0.0465 - mean_squared_error: 0.0045
# Epoch 173/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 261ms/step - accuracy: 0.0023 - loss: 0.0028 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0045
# Epoch 174/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 7.2103e-04 - loss: 0.0024 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0045
# Epoch 175/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 8.4265e-04 - loss: 0.0023 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0044
# Epoch 176/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step - accuracy: 9.8806e-04 - loss: 0.0028 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0044
# Epoch 177/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 257ms/step - accuracy: 2.0847e-04 - loss: 0.0026 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0044
# Epoch 178/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 0.0021 - loss: 0.0027 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0044
# Epoch 179/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 263ms/step - accuracy: 5.3624e-04 - loss: 0.0023 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0044
# Epoch 180/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 279ms/step - accuracy: 0.0026 - loss: 0.0027 - mean_absolute_error: 0.0461 - mean_squared_error: 0.0044
# Epoch 181/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 9.2775e-04 - loss: 0.0024 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0044
# Epoch 182/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 255ms/step - accuracy: 7.3580e-04 - loss: 0.0027 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0044
# Epoch 183/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.0013 - loss: 0.0028 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0044
# Epoch 184/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.0017 - loss: 0.0024 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0044
# Epoch 185/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.0025 - loss: 0.0027 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0043
# Epoch 186/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 277ms/step - accuracy: 8.8398e-04 - loss: 0.0028 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0043
# Epoch 187/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 262ms/step - accuracy: 0.0013 - loss: 0.0027 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0043
# Epoch 188/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 3.0854e-04 - loss: 0.0025 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0043
# Epoch 189/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 0.0029 - loss: 0.0030 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0043
# Epoch 190/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 3.9145e-04 - loss: 0.0023 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0043
# Epoch 191/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 1.4862e-04 - loss: 0.0025 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0043
# Epoch 192/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - accuracy: 0.0021 - loss: 0.0029 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0043
# Epoch 193/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 271ms/step - accuracy: 1.6873e-04 - loss: 0.0027 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0043
# Epoch 194/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 0.0017 - loss: 0.0023 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0043
# Epoch 195/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 277ms/step - accuracy: 0.0013 - loss: 0.0026 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0043
# Epoch 196/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0014 - loss: 0.0027 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0043
# Epoch 197/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 263ms/step - accuracy: 7.9327e-04 - loss: 0.0023 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0042
# Epoch 198/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 9.7425e-04 - loss: 0.0027 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0042
# Epoch 199/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 285ms/step - accuracy: 0.0015 - loss: 0.0027 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0042
# Epoch 200/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 270ms/step - accuracy: 0.0038 - loss: 0.0024 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0042
# Epoch 201/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 0.0012 - loss: 0.0026 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0042
# Epoch 202/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0036 - loss: 0.0030 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0042
# Epoch 203/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 264ms/step - accuracy: 7.5371e-04 - loss: 0.0019 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0042
# Epoch 204/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.0037 - loss: 0.0023 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0042
# Epoch 205/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 281ms/step - accuracy: 0.0031 - loss: 0.0028 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0042
# Epoch 206/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 259ms/step - accuracy: 8.3818e-04 - loss: 0.0024 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0042
# Epoch 207/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 183ms/step - accuracy: 0.0010 - loss: 0.0023 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0042
# Epoch 208/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.0029 - loss: 0.0026 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0042
# Epoch 209/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 8.3881e-04 - loss: 0.0023 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0041
# Epoch 210/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 197ms/step - accuracy: 5.2866e-04 - loss: 0.0024 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0041
# Epoch 211/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 0.0033 - loss: 0.0026 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0041
# Epoch 212/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 268ms/step - accuracy: 0.0015 - loss: 0.0026 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0041
# Epoch 213/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 9.2770e-04 - loss: 0.0030 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0041
# Epoch 214/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 267ms/step - accuracy: 0.0035 - loss: 0.0025 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0041
# Epoch 215/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 283ms/step - accuracy: 0.0029 - loss: 0.0027 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0041
# Epoch 216/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 0.0018 - loss: 0.0024 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0041
# Epoch 217/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 5.4432e-04 - loss: 0.0025 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0041
# Epoch 218/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0018 - loss: 0.0025 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0041
# Epoch 219/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 196ms/step - accuracy: 0.0014 - loss: 0.0024 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0041
# Epoch 220/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 229ms/step - accuracy: 0.0012 - loss: 0.0031 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0041
# Epoch 221/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 282ms/step - accuracy: 0.0039 - loss: 0.0026 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0041
# Epoch 222/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.0020 - loss: 0.0022 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0041
# Epoch 223/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 9.1782e-04 - loss: 0.0027 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0040
# Epoch 224/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 8.2189e-04 - loss: 0.0029 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0040
# Epoch 225/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 0.0023 - loss: 0.0022 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0040
# Epoch 226/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 279ms/step - accuracy: 0.0017 - loss: 0.0023 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0040
# Epoch 227/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.0031 - loss: 0.0026 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0040
# Epoch 228/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.0013 - loss: 0.0024 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0040
# Epoch 229/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 203ms/step - accuracy: 9.2349e-04 - loss: 0.0027 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0040
# Epoch 230/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step - accuracy: 8.6464e-04 - loss: 0.0024 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0040
# Epoch 231/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 3.8177e-04 - loss: 0.0026 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0040
# Epoch 232/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 207ms/step - accuracy: 5.9655e-04 - loss: 0.0026 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0040
# Epoch 233/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 0.0043 - loss: 0.0026 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0040
# Epoch 234/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 241ms/step - accuracy: 0.0015 - loss: 0.0026 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0040
# Epoch 235/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 187ms/step - accuracy: 6.2935e-04 - loss: 0.0023 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0040
# Epoch 236/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 264ms/step - accuracy: 0.0010 - loss: 0.0027 - mean_absolute_error: 0.0440 - mean_squared_error: 0.0040
# Epoch 237/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 282ms/step - accuracy: 0.0011 - loss: 0.0022 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0040
# Epoch 238/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 264ms/step - accuracy: 0.0029 - loss: 0.0022 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0040
# Epoch 239/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0016 - loss: 0.0025 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0039
# Epoch 240/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - accuracy: 7.0495e-04 - loss: 0.0028 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0039
# Epoch 241/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 292ms/step - accuracy: 8.2749e-04 - loss: 0.0023 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0039
# Epoch 242/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 277ms/step - accuracy: 9.7806e-04 - loss: 0.0023 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0039
# Epoch 243/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - accuracy: 6.2220e-04 - loss: 0.0022 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0039
# Epoch 244/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - accuracy: 0.0019 - loss: 0.0024 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0039
# Epoch 245/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 266ms/step - accuracy: 0.0015 - loss: 0.0024 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0039
# Epoch 246/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 8.8806e-04 - loss: 0.0027 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0039
# Epoch 247/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.0017 - loss: 0.0024 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0039
# Epoch 248/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 0.0013 - loss: 0.0022 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0039
# Epoch 249/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 284ms/step - accuracy: 9.2349e-04 - loss: 0.0024 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0039
# Epoch 250/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 0.0030 - loss: 0.0026 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0039
# Epoch 251/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 224ms/step - accuracy: 0.0014 - loss: 0.0026 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0039
# Epoch 252/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 210ms/step - accuracy: 0.0025 - loss: 0.0022 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0039
# Epoch 253/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 7.5426e-04 - loss: 0.0024 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0039
# Epoch 254/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 280ms/step - accuracy: 0.0017 - loss: 0.0024 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0039
# Epoch 255/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0013 - loss: 0.0025 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0039
# Epoch 256/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.0022 - loss: 0.0023 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0038
# Epoch 257/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.0024 - loss: 0.0024 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0038
# Epoch 258/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 275ms/step - accuracy: 0.0018 - loss: 0.0024 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0038
# Epoch 259/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 231ms/step - accuracy: 7.4584e-04 - loss: 0.0024 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0038
# Epoch 260/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 221ms/step - accuracy: 0.0012 - loss: 0.0024 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0038
# Epoch 261/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 7.2103e-04 - loss: 0.0022 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0038
# Epoch 262/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 265ms/step - accuracy: 6.4143e-04 - loss: 0.0027 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0038
# Epoch 263/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 22s 287ms/step - accuracy: 6.7427e-04 - loss: 0.0025 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0038
# Epoch 264/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 7.1293e-04 - loss: 0.0024 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0038
# Epoch 265/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 3.9145e-04 - loss: 0.0023 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0038
# Epoch 266/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 0.0028 - loss: 0.0025 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0038
# Epoch 267/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 200ms/step - accuracy: 0.0010 - loss: 0.0027 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0038
# Epoch 268/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - accuracy: 0.0016 - loss: 0.0024 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0038
# Epoch 269/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 292ms/step - accuracy: 0.0015 - loss: 0.0024 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0038
# Epoch 270/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 9.5617e-04 - loss: 0.0025 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0038
# Epoch 271/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 234ms/step - accuracy: 3.6580e-04 - loss: 0.0026 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0038
# Epoch 272/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.0014 - loss: 0.0025 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0038
# Epoch 273/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 215ms/step - accuracy: 7.5937e-04 - loss: 0.0028 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0038
# Epoch 274/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.0014 - loss: 0.0027 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0038
# Epoch 275/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 8.6073e-04 - loss: 0.0023 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0038
# Epoch 276/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.0017 - loss: 0.0026 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0038
# Epoch 277/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.0041 - loss: 0.0028 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0037
# Epoch 278/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 209ms/step - accuracy: 0.0038 - loss: 0.0023 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0037
# Epoch 279/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 0.0019 - loss: 0.0021 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0037
# Epoch 280/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 222ms/step - accuracy: 0.0012 - loss: 0.0026 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0037
# Epoch 281/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 214ms/step - accuracy: 0.0057 - loss: 0.0028 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0037
# Epoch 282/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 273ms/step - accuracy: 8.9414e-04 - loss: 0.0022 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0037
# Epoch 283/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0033 - loss: 0.0025 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0037
# Epoch 284/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 0.0010 - loss: 0.0028 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0037
# Epoch 285/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 253ms/step - accuracy: 0.0022 - loss: 0.0022 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0037
# Epoch 286/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 8s 197ms/step - accuracy: 5.4388e-04 - loss: 0.0024 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0037
# Epoch 287/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - accuracy: 0.0018 - loss: 0.0026 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0037
# Epoch 288/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 278ms/step - accuracy: 8.2496e-04 - loss: 0.0029 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0037
# Epoch 289/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 0.0017 - loss: 0.0024 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0037
# Epoch 290/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 289ms/step - accuracy: 0.0037 - loss: 0.0022 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0037
# Epoch 291/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 12s 278ms/step - accuracy: 0.0015 - loss: 0.0024 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0037
# Epoch 292/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 0.0024 - loss: 0.0027 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0037
# Epoch 293/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 271ms/step - accuracy: 0.0011 - loss: 0.0024 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0037
# Epoch 294/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 325ms/step - accuracy: 0.0014 - loss: 0.0025 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0037
# Epoch 295/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 321ms/step - accuracy: 7.8023e-04 - loss: 0.0023 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0037
# Epoch 296/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 11s 270ms/step - accuracy: 5.3496e-04 - loss: 0.0024 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0037
# Epoch 297/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 24s 584ms/step - accuracy: 4.9551e-04 - loss: 0.0020 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0037
# Epoch 298/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 23s 556ms/step - accuracy: 8.8195e-04 - loss: 0.0025 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0037
# Epoch 299/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 19s 459ms/step - accuracy: 7.5426e-04 - loss: 0.0026 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0037
# Epoch 300/300
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 21s 491ms/step - accuracy: 0.0016 - loss: 0.0023 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0037

# %%
model.save('8_15_23_300_LXg_TRYHARD.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
data_testing.head()
# Out:
#         Close       Date
# 1409  73.0102 2017-05-26
# 1410  73.0024 2017-05-25
# 1411  73.3138 2017-05-24
# 1412  73.3520 2017-05-23
# 1413  72.4482 2017-05-22

# %%
data_training.head()
# Out:
#     Close       Date
# 0  134.10 2022-12-30
# 1  133.22 2022-12-29
# 2  132.46 2022-12-28
# 3  131.74 2022-12-27
# 4  131.28 2022-12-23

# %%
# We need previous 100 days data and we need to compare and append the list.
past_100_days=data_training.tail(100)
final_df=pd.concat([past_100_days,data_testing],ignore_index=True)

# %%
final_df.head()
# Out:
#      Close       Date
# 0  84.7661 2017-10-18
# 1  84.4487 2017-10-17
# 2  84.6383 2017-10-16
# 3  82.9240 2017-10-13
# 4  83.0380 2017-10-12

# %%
input_data = scaler.fit_transform(final_df[['Close']])
input_data
# Out:
# array([[1.        ],
#        [0.99225636],
#        [0.99688205],
#        [0.95505813],
#        [0.95783939],
#        [0.97579077],
#        [0.98192664],
#        [0.96670774],
#        [0.97746929],
#        [0.98108738],
#        [0.95386023],
#        [0.97451968],
#        [0.96392647],
#        [0.936004  ],
#        [0.93329592],
#        [0.92907523],
#        [0.89803725],
#        [0.90678605],
#        [0.92179026],
#        [0.92596216],
#        [0.91690108],
#        [0.90302402],
#        [0.88164241],
#        [0.85438843],
#        [0.8407041 ],
#        [0.84451492],
#        [0.83909633],
#        [0.8159191 ],
#        [0.78720373],
#        [0.78958   ],
#        [0.82270149],
#        [0.81011747],
#        [0.85606695],
#        [0.83909633],
#        [0.84786952],
#        [0.84343657],
#        [0.85398343],
#        [0.86004611],
#        [0.85223172],
#        [0.85539603],
#        [0.85314417],
#        [0.83356063],
#        [0.83586128],
#        [0.83404126],
#        [0.86421801],
#        [0.87766325],
#        [0.87263013],
#        [0.85019457],
#        [0.86635032],
#        [0.89446552],
#        [0.89762738],
#        [0.90477085],
#        [0.89719799],
#        [0.87279847],
#        [0.88561914],
#        [0.88398941],
#        [0.85817729],
#        [0.8472718 ],
#        [0.85290264],
#        [0.86086097],
#        [0.87912463],
#        [0.8472718 ],
#        [0.83909633],
#        [0.84554448],
#        [0.84554448],
#        [0.84283641],
#        [0.84957244],
#        [0.86759701],
#        [0.88538005],
#        [0.87303756],
#        [0.87979799],
#        [0.88727326],
#        [0.90117472],
#        [0.89130122],
#        [0.89762738],
#        [0.87809508],
#        [0.83926467],
#        [0.83406565],
#        [0.80633104],
#        [0.76939629],
#        [0.75245008],
#        [0.74454054],
#        [0.74784879],
#        [0.74998109],
#        [0.75834685],
#        [0.76980373],
#        [0.73039999],
#        [0.73845347],
#        [0.74933457],
#        [0.753121  ],
#        [0.74703392],
#        [0.7465777 ],
#        [0.70463179],
#        [0.68298913],
#        [0.6631421 ],
#        [0.65961916],
#        [0.65647926],
#        [0.6651817 ],
#        [0.64622028],
#        [0.682772  ],
#        [0.71319029],
#        [0.71299999],
#        [0.72059724],
#        [0.72152921],
#        [0.69947912],
#        [0.70110885],
#        [0.68406992],
#        [0.69046684],
#        [0.76019127],
#        [0.75453603],
#        [0.74578723],
#        [0.750774  ],
#        [0.75642924],
#        [0.7422155 ],
#        [0.74954926],
#        [0.74749015],
#        [0.74954926],
#        [0.74749015],
#        [0.73701404],
#        [0.74868805],
#        [0.74749015],
#        [0.76019127],
#        [0.77723508],
#        [0.77375849],
#        [0.75791502],
#        [0.69576589],
#        [0.71719141],
#        [0.69444844],
#        [0.70901838],
#        [0.72368835],
#        [0.69315052],
#        [0.71402954],
#        [0.72095588],
#        [0.72409578],
#        [0.73039999],
#        [0.7366554 ],
#        [0.73056589],
#        [0.75388951],
#        [0.74784879],
#        [0.75448723],
#        [0.77922344],
#        [0.76342877],
#        [0.77030631],
#        [0.74207156],
#        [0.74310355],
#        [0.74518706],
#        [0.74806348],
#        [0.74518706],
#        [0.79993413],
#        [0.81347451],
#        [0.8333679 ],
#        [0.83521476],
#        [0.83068422],
#        [0.82756871],
#        [0.82591459],
#        [0.83186016],
#        [0.82440441],
#        [0.82855191],
#        [0.83919392],
#        [0.85740879],
#        [0.84370006],
#        [0.87399636],
#        [0.81213267],
#        [0.80819986],
#        [0.80618954],
#        [0.82277468],
#        [0.82135965],
#        [0.8202569 ],
#        [0.80408163],
#        [0.81038096],
#        [0.81148371],
#        [0.79019969],
#        [0.76091099],
#        [0.73706283],
#        [0.7412323 ],
#        [0.71549093],
#        [0.7312856 ],
#        [0.7322932 ],
#        [0.74080291],
#        [0.68708784],
#        [0.69456555],
#        [0.68794906],
#        [0.71697671],
#        [0.73562585],
#        [0.73183698],
#        [0.71697671],
#        [0.68972517],
#        [0.66882418],
#        [0.66800932],
#        [0.66053161],
#        [0.67356942],
#        [0.66549154],
#        [0.73082938],
#        [0.72124376],
#        [0.73876331],
#        [0.72522293],
#        [0.72011662],
#        [0.71879674],
#        [0.71855764],
#        [0.73519402],
#        [0.73183698],
#        [0.71249497],
#        [0.70425119],
#        [0.71685717],
#        [0.72987301],
#        [0.7281701 ],
#        [0.72486185],
#        [0.72191468],
#        [0.7174305 ],
#        [0.69480464],
#        [0.6845969 ],
#        [0.7065006 ],
#        [0.68035181],
#        [0.68092758],
#        [0.68035181],
#        [0.69602937],
#        [0.68835893],
#        [0.66668944],
#        [0.6588287 ],
#        [0.65000915],
#        [0.61575564],
#        [0.61966405],
#        [0.5862498 ],
#        [0.56043768],
#        [0.54802201],
#        [0.55856887],
#        [0.55914464],
#        [0.55238421],
#        [0.54250826],
#        [0.53546239],
#        [0.54183734],
#        [0.52906303],
#        [0.56949876],
#        [0.57266062],
#        [0.51446625],
#        [0.5136026 ],
#        [0.44344633],
#        [0.37700575],
#        [0.37391219],
#        [0.33014626],
#        [0.34294497],
#        [0.34915403],
#        [0.35507276],
#        [0.36108909],
#        [0.35797114],
#        [0.36046452],
#        [0.3584298 ],
#        [0.35154982],
#        [0.35305756],
#        [0.34527001],
#        [0.34042963],
#        [0.3423936 ],
#        [0.32892397],
#        [0.31794528],
#        [0.3251595 ],
#        [0.32973883],
#        [0.33776791],
#        [0.34148359],
#        [0.34829037],
#        [0.33736048],
#        [0.33239811],
#        [0.32870683],
#        [0.30622492],
#        [0.29452895],
#        [0.29603913],
#        [0.27681423],
#        [0.29853008],
#        [0.29138905],
#        [0.27949791],
#        [0.30960391],
#        [0.31245593],
#        [0.3011918 ],
#        [0.29340181],
#        [0.28788807],
#        [0.28031521],
#        [0.29709309],
#        [0.29213072],
#        [0.29491199],
#        [0.30569794],
#        [0.29733218],
#        [0.30960391],
#        [0.30775949],
#        [0.31348793],
#        [0.31459068],
#        [0.30878905],
#        [0.31471022],
#        [0.31471022],
#        [0.3033729 ],
#        [0.28843944],
#        [0.28542152],
#        [0.28304768],
#        [0.27930761],
#        [0.27990778],
#        [0.28113007],
#        [0.28304768],
#        [0.2817034 ],
#        [0.27806336],
#        [0.27827805],
#        [0.27010503],
#        [0.2728863 ],
#        [0.26921698],
#        [0.28129841],
#        [0.2860656 ],
#        [0.29016431],
#        [0.25450065],
#        [0.25646706],
#        [0.23585152],
#        [0.23894507],
#        [0.24239482],
#        [0.24505654],
#        [0.24980177],
#        [0.24572746],
#        [0.2403357 ],
#        [0.24378545],
#        [0.23671518],
#        [0.24157996],
#        [0.24016736],
#        [0.24222892],
#        [0.24673262],
#        [0.24548837],
#        [0.22578528],
#        [0.22667334],
#        [0.20761677],
#        [0.19855813],
#        [0.17288508],
#        [0.16495358],
#        [0.15184015],
#        [0.18685973],
#        [0.19508155],
#        [0.17597863],
#        [0.14182271],
#        [0.10299474],
#        [0.14347683],
#        [0.23388755],
#        [0.20670676],
#        [0.21162033],
#        [0.19982678],
#        [0.19788721],
#        [0.19668688],
#        [0.1916074 ],
#        [0.19383486],
#        [0.21804409],
#        [0.2296449 ],
#        [0.24812325],
#        [0.25836027],
#        [0.25442746],
#        [0.2589824 ],
#        [0.24599095],
#        [0.26969516],
#        [0.26729936],
#        [0.25876526],
#        [0.2619808 ],
#        [0.25378338],
#        [0.26375203],
#        [0.24378545],
#        [0.22192566],
#        [0.22295766],
#        [0.22048867],
#        [0.23367042],
#        [0.18532759],
#        [0.18532759],
#        [0.17597863],
#        [0.18760384],
#        [0.18834795],
#        [0.19304439],
#        [0.17616893],
#        [0.18410286],
#        [0.1767447 ],
#        [0.18348073],
#        [0.203662  ],
#        [0.22856655],
#        [0.2165827 ],
#        [0.22482648],
#        [0.23513424],
#        [0.23144053],
#        [0.22482648],
#        [0.23225783],
#        [0.22482648],
#        [0.23772034],
#        [0.21907608],
#        [0.19769448],
#        [0.1896166 ],
#        [0.20421338],
#        [0.18803567],
#        [0.13690913],
#        [0.11500299],
#        [0.10563207],
#        [0.09707357],
#        [0.12739427],
#        [0.11819169],
#        [0.135377  ],
#        [0.13997829],
#        [0.12691609],
#        [0.13671884],
#        [0.12305647],
#        [0.13055613],
#        [0.13214194],
#        [0.14136892],
#        [0.14745599],
#        [0.15188894],
#        [0.15234761],
#        [0.11737683],
#        [0.12077778],
#        [0.12650622],
#        [0.12487649],
#        [0.12926309],
#        [0.11452237],
#        [0.12487649],
#        [0.11795016],
#        [0.14136892],
#        [0.14362321],
#        [0.14179831],
#        [0.13774839],
#        [0.12650622],
#        [0.06802396],
#        [0.09295046],
#        [0.0822377 ],
#        [0.06474011],
#        [0.06435708],
#        [0.11382949],
#        [0.0986789 ],
#        [0.0984642 ],
#        [0.11775742],
#        [0.10932091],
#        [0.0919697 ],
#        [0.00275687],
#        [0.05225368],
#        [0.06593801],
#        [0.07276919],
#        [0.09716872],
#        [0.11037486],
#        [0.09036193],
#        [0.08264513],
#        [0.11967503],
#        [0.13252254],
#        [0.0877978 ],
#        [0.08288422],
#        [0.08372348],
#        [0.05503251],
#        [0.08111056],
#        [0.04676434],
#        [0.0520585 ],
#        [0.0822377 ],
#        [0.08288422],
#        [0.10632494],
#        [0.08892494],
#        [0.12161704],
#        [0.11905291],
#        [0.12077778],
#        [0.14812691],
#        [0.1993486 ],
#        [0.21787575],
#        [0.21569465],
#        [0.25550581],
#        [0.2666504 ],
#        [0.2761921 ],
#        [0.26248338],
#        [0.26686998],
#        [0.26943167],
#        [0.24843554],
#        [0.24562987],
#        [0.22278932],
#        [0.26037059],
#        [0.28549227],
#        [0.25677934],
#        [0.22010564],
#        [0.21610208],
#        [0.24695219],
#        [0.24393183],
#        [0.25394928],
#        [0.27494541],
#        [0.2926333 ],
#        [0.25083133],
#        [0.26801664],
#        [0.2870976 ],
#        [0.26842651],
#        [0.27827805],
#        [0.27207143],
#        [0.27041731],
#        [0.27247643],
#        [0.28570697],
#        [0.28805641],
#        [0.2839089 ],
#        [0.25742342],
#        [0.26506947],
#        [0.24601535],
#        [0.25481294],
#        [0.28184979],
#        [0.28843944],
#        [0.282711  ],
#        [0.30411457],
#        [0.26358613],
#        [0.25174378],
#        [0.25040194],
#        [0.24562987],
#        [0.21976896],
#        [0.23899386],
#        [0.24479305],
#        [0.20757042],
#        [0.21267429],
#        [0.21207656],
#        [0.19848494],
#        [0.17585908],
#        [0.1850641 ],
#        [0.17904778],
#        [0.18321724],
#        [0.17243129],
#        [0.13427425],
#        [0.1656733 ],
#        [0.16898154],
#        [0.17319736],
#        [0.17722532],
#        [0.17722532],
#        [0.17569074],
#        [0.17506862],
#        [0.1507618 ],
#        [0.15419203],
#        [0.14520414],
#        [0.12274418],
#        [0.12550106],
#        [0.15522159],
#        [0.13036583],
#        [0.13872916],
#        [0.1440526 ],
#        [0.1547678 ],
#        [0.14462837],
#        [0.1787111 ],
#        [0.20831209],
#        [0.1971919 ],
#        [0.17327055],
#        [0.17684229],
#        [0.17885504],
#        [0.16931578],
#        [0.18875294],
#        [0.15579736],
#        [0.17926248],
#        [0.17703258],
#        [0.1547678 ],
#        [0.20759481],
#        [0.20812179],
#        [0.21509448],
#        [0.18383937],
#        [0.12415922],
#        [0.13094161],
#        [0.19755053],
#        [0.24412213],
#        [0.2772241 ],
#        [0.2893031 ],
#        [0.28659502],
#        [0.28304768],
#        [0.27614575],
#        [0.27005624],
#        [0.28971053],
#        [0.30289227],
#        [0.28616319],
#        [0.29014236],
#        [0.29963282],
#        [0.29436061],
#        [0.29567806],
#        [0.29567806],
#        [0.30581749],
#        [0.30378033],
#        [0.28616319],
#        [0.28532393],
#        [0.30322895],
#        [0.31773058],
#        [0.32657453],
#        [0.30703978],
#        [0.31022848],
#        [0.30919648],
#        [0.31617161],
#        [0.30881345],
#        [0.30581749],
#        [0.28695366],
#        [0.26619662],
#        [0.24757188],
#        [0.23393391],
#        [0.26128304],
#        [0.27185186],
#        [0.27556998],
#        [0.28659502],
#        [0.27161277],
#        [0.26049258],
#        [0.29512668],
#        [0.28915915],
#        [0.29646852],
#        [0.31097015],
#        [0.29529502],
#        [0.27794137],
#        [0.29177208],
#        [0.27914171],
#        [0.283743  ],
#        [0.27612135],
#        [0.28124962],
#        [0.28669017],
#        [0.28143992],
#        [0.26006319],
#        [0.25437867],
#        [0.26490357],
#        [0.24338046],
#        [0.25066543],
#        [0.23721776],
#        [0.23844249],
#        [0.23247496],
#        [0.2407407 ],
#        [0.24608854],
#        [0.23144053],
#        [0.24608854],
#        [0.24966027],
#        [0.24630323],
#        [0.25673055],
#        [0.2450785 ],
#        [0.23443893],
#        [0.23774473],
#        [0.22736621],
#        [0.22413116],
#        [0.22592922],
#        [0.22676848],
#        [0.20718494],
#        [0.19570611],
#        [0.20512583],
#        [0.21159594],
#        [0.18956781],
#        [0.18261952],
#        [0.18935311],
#        [0.17264599],
#        [0.16444856],
#        [0.16957927],
#        [0.17355844],
#        [0.17629091],
#        [0.16387279],
#        [0.18225844],
#        [0.17432451],
#        [0.19362016],
#        [0.20136136],
#        [0.17832807],
#        [0.1591056 ],
#        [0.15174744],
#        [0.14723886],
#        [0.13897313],
#        [0.13499152],
#        [0.12749186],
#        [0.12847262],
#        [0.11718409],
#        [0.12171463],
#        [0.12916794],
#        [0.10153336],
#        [0.10131622],
#        [0.10277761],
#        [0.11943594],
#        [0.13273723],
#        [0.14472596],
#        [0.13391317],
#        [0.14472596],
#        [0.14196909],
#        [0.14671188],
#        [0.13000476],
#        [0.12506923],
#        [0.11504934],
#        [0.10953804],
#        [0.13976359],
#        [0.12784805],
#        [0.14963709],
#        [0.15222562],
#        [0.14901497],
#        [0.14505776],
#        [0.1355429 ],
#        [0.14134452],
#        [0.13273723],
#        [0.12648182],
#        [0.09752979],
#        [0.10644693],
#        [0.09520475],
#        [0.09793723],
#        [0.11231687],
#        [0.10383156],
#        [0.1018676 ],
#        [0.07828293],
#        [0.08017615],
#        [0.06749698],
#        [0.06895837],
#        [0.04693024],
#        [0.03933298],
#        [0.04592508],
#        [0.02135721],
#        [0.        ],
#        [0.02533394],
#        [0.00719226],
#        [0.03571246],
#        [0.04693024],
#        [0.04515901],
#        [0.0630128 ],
#        [0.02957903],
#        [0.02610244],
#        [0.0304866 ],
#        [0.01200825],
#        [0.0477207 ],
#        [0.08760506],
#        [0.08741476],
#        [0.09733706],
#        [0.11795016],
#        [0.09206485],
#        [0.09033753],
#        [0.12113886],
#        [0.1592715 ]])

# %%
input_data.shape
# Out:
# (705, 1)

# %%
x_test = []
y_test = []

for i in range(100,input_data.shape[0]):
  x_test.append(input_data[i-100: i])
  y_test.append(input_data[i, 0])

# %%
x_test,y_test= np.array(x_test),np.array(y_test)

print(x_test.shape)
print(y_test.shape)
# Out:
# (605, 100, 1)
# (605,)

# %%
# Making Predictions

y_predicted = model.predict(x_test)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 15s 447ms/step

# %%
y_predicted.shape
# Out:
# (605, 1)

# %%
y_test
# Out:
# array([0.71319029, 0.71299999, 0.72059724, 0.72152921, 0.69947912,
#        0.70110885, 0.68406992, 0.69046684, 0.76019127, 0.75453603,
#        0.74578723, 0.750774  , 0.75642924, 0.7422155 , 0.74954926,
#        0.74749015, 0.74954926, 0.74749015, 0.73701404, 0.74868805,
#        0.74749015, 0.76019127, 0.77723508, 0.77375849, 0.75791502,
#        0.69576589, 0.71719141, 0.69444844, 0.70901838, 0.72368835,
#        0.69315052, 0.71402954, 0.72095588, 0.72409578, 0.73039999,
#        0.7366554 , 0.73056589, 0.75388951, 0.74784879, 0.75448723,
#        0.77922344, 0.76342877, 0.77030631, 0.74207156, 0.74310355,
#        0.74518706, 0.74806348, 0.74518706, 0.79993413, 0.81347451,
#        0.8333679 , 0.83521476, 0.83068422, 0.82756871, 0.82591459,
#        0.83186016, 0.82440441, 0.82855191, 0.83919392, 0.85740879,
#        0.84370006, 0.87399636, 0.81213267, 0.80819986, 0.80618954,
#        0.82277468, 0.82135965, 0.8202569 , 0.80408163, 0.81038096,
#        0.81148371, 0.79019969, 0.76091099, 0.73706283, 0.7412323 ,
#        0.71549093, 0.7312856 , 0.7322932 , 0.74080291, 0.68708784,
#        0.69456555, 0.68794906, 0.71697671, 0.73562585, 0.73183698,
#        0.71697671, 0.68972517, 0.66882418, 0.66800932, 0.66053161,
#        0.67356942, 0.66549154, 0.73082938, 0.72124376, 0.73876331,
#        0.72522293, 0.72011662, 0.71879674, 0.71855764, 0.73519402,
#        0.73183698, 0.71249497, 0.70425119, 0.71685717, 0.72987301,
#        0.7281701 , 0.72486185, 0.72191468, 0.7174305 , 0.69480464,
#        0.6845969 , 0.7065006 , 0.68035181, 0.68092758, 0.68035181,
#        0.69602937, 0.68835893, 0.66668944, 0.6588287 , 0.65000915,
#        0.61575564, 0.61966405, 0.5862498 , 0.56043768, 0.54802201,
#        0.55856887, 0.55914464, 0.55238421, 0.54250826, 0.53546239,
#        0.54183734, 0.52906303, 0.56949876, 0.57266062, 0.51446625,
#        0.5136026 , 0.44344633, 0.37700575, 0.37391219, 0.33014626,
#        0.34294497, 0.34915403, 0.35507276, 0.36108909, 0.35797114,
#        0.36046452, 0.3584298 , 0.35154982, 0.35305756, 0.34527001,
#        0.34042963, 0.3423936 , 0.32892397, 0.31794528, 0.3251595 ,
#        0.32973883, 0.33776791, 0.34148359, 0.34829037, 0.33736048,
#        0.33239811, 0.32870683, 0.30622492, 0.29452895, 0.29603913,
#        0.27681423, 0.29853008, 0.29138905, 0.27949791, 0.30960391,
#        0.31245593, 0.3011918 , 0.29340181, 0.28788807, 0.28031521,
#        0.29709309, 0.29213072, 0.29491199, 0.30569794, 0.29733218,
#        0.30960391, 0.30775949, 0.31348793, 0.31459068, 0.30878905,
#        0.31471022, 0.31471022, 0.3033729 , 0.28843944, 0.28542152,
#        0.28304768, 0.27930761, 0.27990778, 0.28113007, 0.28304768,
#        0.2817034 , 0.27806336, 0.27827805, 0.27010503, 0.2728863 ,
#        0.26921698, 0.28129841, 0.2860656 , 0.29016431, 0.25450065,
#        0.25646706, 0.23585152, 0.23894507, 0.24239482, 0.24505654,
#        0.24980177, 0.24572746, 0.2403357 , 0.24378545, 0.23671518,
#        0.24157996, 0.24016736, 0.24222892, 0.24673262, 0.24548837,
#        0.22578528, 0.22667334, 0.20761677, 0.19855813, 0.17288508,
#        0.16495358, 0.15184015, 0.18685973, 0.19508155, 0.17597863,
#        0.14182271, 0.10299474, 0.14347683, 0.23388755, 0.20670676,
#        0.21162033, 0.19982678, 0.19788721, 0.19668688, 0.1916074 ,
#        0.19383486, 0.21804409, 0.2296449 , 0.24812325, 0.25836027,
#        0.25442746, 0.2589824 , 0.24599095, 0.26969516, 0.26729936,
#        0.25876526, 0.2619808 , 0.25378338, 0.26375203, 0.24378545,
#        0.22192566, 0.22295766, 0.22048867, 0.23367042, 0.18532759,
#        0.18532759, 0.17597863, 0.18760384, 0.18834795, 0.19304439,
#        0.17616893, 0.18410286, 0.1767447 , 0.18348073, 0.203662  ,
#        0.22856655, 0.2165827 , 0.22482648, 0.23513424, 0.23144053,
#        0.22482648, 0.23225783, 0.22482648, 0.23772034, 0.21907608,
#        0.19769448, 0.1896166 , 0.20421338, 0.18803567, 0.13690913,
#        0.11500299, 0.10563207, 0.09707357, 0.12739427, 0.11819169,
#        0.135377  , 0.13997829, 0.12691609, 0.13671884, 0.12305647,
#        0.13055613, 0.13214194, 0.14136892, 0.14745599, 0.15188894,
#        0.15234761, 0.11737683, 0.12077778, 0.12650622, 0.12487649,
#        0.12926309, 0.11452237, 0.12487649, 0.11795016, 0.14136892,
#        0.14362321, 0.14179831, 0.13774839, 0.12650622, 0.06802396,
#        0.09295046, 0.0822377 , 0.06474011, 0.06435708, 0.11382949,
#        0.0986789 , 0.0984642 , 0.11775742, 0.10932091, 0.0919697 ,
#        0.00275687, 0.05225368, 0.06593801, 0.07276919, 0.09716872,
#        0.11037486, 0.09036193, 0.08264513, 0.11967503, 0.13252254,
#        0.0877978 , 0.08288422, 0.08372348, 0.05503251, 0.08111056,
#        0.04676434, 0.0520585 , 0.0822377 , 0.08288422, 0.10632494,
#        0.08892494, 0.12161704, 0.11905291, 0.12077778, 0.14812691,
#        0.1993486 , 0.21787575, 0.21569465, 0.25550581, 0.2666504 ,
#        0.2761921 , 0.26248338, 0.26686998, 0.26943167, 0.24843554,
#        0.24562987, 0.22278932, 0.26037059, 0.28549227, 0.25677934,
#        0.22010564, 0.21610208, 0.24695219, 0.24393183, 0.25394928,
#        0.27494541, 0.2926333 , 0.25083133, 0.26801664, 0.2870976 ,
#        0.26842651, 0.27827805, 0.27207143, 0.27041731, 0.27247643,
#        0.28570697, 0.28805641, 0.2839089 , 0.25742342, 0.26506947,
#        0.24601535, 0.25481294, 0.28184979, 0.28843944, 0.282711  ,
#        0.30411457, 0.26358613, 0.25174378, 0.25040194, 0.24562987,
#        0.21976896, 0.23899386, 0.24479305, 0.20757042, 0.21267429,
#        0.21207656, 0.19848494, 0.17585908, 0.1850641 , 0.17904778,
#        0.18321724, 0.17243129, 0.13427425, 0.1656733 , 0.16898154,
#        0.17319736, 0.17722532, 0.17722532, 0.17569074, 0.17506862,
#        0.1507618 , 0.15419203, 0.14520414, 0.12274418, 0.12550106,
#        0.15522159, 0.13036583, 0.13872916, 0.1440526 , 0.1547678 ,
#        0.14462837, 0.1787111 , 0.20831209, 0.1971919 , 0.17327055,
#        0.17684229, 0.17885504, 0.16931578, 0.18875294, 0.15579736,
#        0.17926248, 0.17703258, 0.1547678 , 0.20759481, 0.20812179,
#        0.21509448, 0.18383937, 0.12415922, 0.13094161, 0.19755053,
#        0.24412213, 0.2772241 , 0.2893031 , 0.28659502, 0.28304768,
#        0.27614575, 0.27005624, 0.28971053, 0.30289227, 0.28616319,
#        0.29014236, 0.29963282, 0.29436061, 0.29567806, 0.29567806,
#        0.30581749, 0.30378033, 0.28616319, 0.28532393, 0.30322895,
#        0.31773058, 0.32657453, 0.30703978, 0.31022848, 0.30919648,
#        0.31617161, 0.30881345, 0.30581749, 0.28695366, 0.26619662,
#        0.24757188, 0.23393391, 0.26128304, 0.27185186, 0.27556998,
#        0.28659502, 0.27161277, 0.26049258, 0.29512668, 0.28915915,
#        0.29646852, 0.31097015, 0.29529502, 0.27794137, 0.29177208,
#        0.27914171, 0.283743  , 0.27612135, 0.28124962, 0.28669017,
#        0.28143992, 0.26006319, 0.25437867, 0.26490357, 0.24338046,
#        0.25066543, 0.23721776, 0.23844249, 0.23247496, 0.2407407 ,
#        0.24608854, 0.23144053, 0.24608854, 0.24966027, 0.24630323,
#        0.25673055, 0.2450785 , 0.23443893, 0.23774473, 0.22736621,
#        0.22413116, 0.22592922, 0.22676848, 0.20718494, 0.19570611,
#        0.20512583, 0.21159594, 0.18956781, 0.18261952, 0.18935311,
#        0.17264599, 0.16444856, 0.16957927, 0.17355844, 0.17629091,
#        0.16387279, 0.18225844, 0.17432451, 0.19362016, 0.20136136,
#        0.17832807, 0.1591056 , 0.15174744, 0.14723886, 0.13897313,
#        0.13499152, 0.12749186, 0.12847262, 0.11718409, 0.12171463,
#        0.12916794, 0.10153336, 0.10131622, 0.10277761, 0.11943594,
#        0.13273723, 0.14472596, 0.13391317, 0.14472596, 0.14196909,
#        0.14671188, 0.13000476, 0.12506923, 0.11504934, 0.10953804,
#        0.13976359, 0.12784805, 0.14963709, 0.15222562, 0.14901497,
#        0.14505776, 0.1355429 , 0.14134452, 0.13273723, 0.12648182,
#        0.09752979, 0.10644693, 0.09520475, 0.09793723, 0.11231687,
#        0.10383156, 0.1018676 , 0.07828293, 0.08017615, 0.06749698,
#        0.06895837, 0.04693024, 0.03933298, 0.04592508, 0.02135721,
#        0.        , 0.02533394, 0.00719226, 0.03571246, 0.04693024,
#        0.04515901, 0.0630128 , 0.02957903, 0.02610244, 0.0304866 ,
#        0.01200825, 0.0477207 , 0.08760506, 0.08741476, 0.09733706,
#        0.11795016, 0.09206485, 0.09033753, 0.12113886, 0.1592715 ])

# %%
y_predicted

from sklearn.metrics import mean_squared_error, r2_score

# Calculate Mean Squared Error
mse = mean_squared_error(y_test,y_predicted)
print("Mean Squared Error: ",mse)

# Calculate R-Squared Score
r2 = r2_score(y_test,y_predicted)
print("R-Squared Score: ",r2)
# Out:
# Mean Squared Error:  0.0007569133661505102
# R-Squared Score:  0.985658403737152

# %%
import numpy as np
from sklearn.metrics import f1_score

threshold=0.4
p_predicted_binary = (y_predicted > threshold).astype(int)
y_test_binary = (y_test).astype(int)

f1 = f1_score(y_test_binary, p_predicted_binary , average='micro')
print("F1 Score: ",f1)
# Out:
# F1 Score:  0.768595041322314

# %% [markdown]
# # Threshold Selection
#
# - Threshold Selection: Experiment with different thresholds for converting continuous predictions to binary classes. The optimal threshold depends on your specific business goals (e.g., minimizing false positives vs. false negatives).

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

threshold = 0.4  # Adjust as needed
y_pred_binary = (y_predicted > threshold).astype(int)
y_test_binary = (y_test > threshold).astype(int)

precision = precision_score(y_test_binary, y_pred_binary)
recall = recall_score(y_test_binary, y_pred_binary)

accuracy = accuracy_score(y_test_binary, y_pred_binary)

print("Precision:", precision)
print("Recall:", recall)
print("Accuracy:", accuracy)
# Out:
# Precision: 0.9785714285714285
# Recall: 1.0
# Accuracy: 0.9950413223140496

# %% [markdown]
# **Threshold**: The threshold determines how you classify a price change as an increase or not. Adjust it based on your problem definition.
# Binarization: The code converts the continuous values to 0 (no increase) or 1 (increase) based on the threshold.
#
# **Binarization**: The code converts the continuous values to 0 (no increase) or 1 (increase) based on the threshold.
#
# **recall_score**: This function calculates the recall, which is the ratio of true positives to the sum of true positives and false negatives. It measures how well your model identifies all the actual positive instances (price increases in this case).

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_test_binary, p_predicted_binary)
print("Recall:", recall)
# Out:
# Recall: 1.0

# %%
scaler.scale_
# Out:
# array([0.02439709])

# %%
scale_factor=1/scaler.scale_
y_predicted= y_predicted* scale_factor
y_test = y_test * scale_factor

# %%
fig=plt.figure(figsize=(12,6))
fig.patch.set_facecolor('#A59DDF')

ax=plt.axes()
ax.set_facecolor('#211970')

plt.grid(True,linestyle='--',color='#626784')
plt.plot(y_test,'#A720C4',label="Original price")
plt.plot(y_predicted,'#DFB729',label="Predicted price")

plt.xlabel('Time')
plt.ylabel('Stock Price($)')
plt.legend()
plt.show()

# %% [markdown]
# #Lstm+XGBoost

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import xgboost as xgb

# ... (Load and preprocess your time series data) ...

# Scale numerical features
scaler = MinMaxScaler(feature_range=(0,1))
data_training_array = scaler.fit_transform(data_training[['Close']])

y = data_training['Close'].values # Choosen Feature


# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
   data_training_array, y, test_size=0.2, shuffle=False
)

# Reshape data for LSTM (samples, timesteps, features)
X_train_lstm = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test_lstm = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
lstm_features_train = model.predict(X_train_lstm)
lstm_features_test = model.predict(X_test_lstm)

# Train XGBoost model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(lstm_features_train, y_train)

# Make predictions
y_pred = model_xgb.predict(lstm_features_test)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Evaluate the performance of the combined model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (Combined Model):", mse)
print("R-squared Score (Combined Model):", r2)
# Out:
# Mean Squared Error (Combined Model): 1.0762549727238626
# R-squared Score (Combined Model): 0.986069111004322
