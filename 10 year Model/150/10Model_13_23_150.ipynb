# %%
# !pip install pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (4.9.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (2.1.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (2.32.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
import pandas_datareader.data as web
start='2013-01-01'
end='2023-01-01'

df=web.DataReader('JPM','stooq',start,end)
df.head()
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2022-12-30  132.81  134.33  132.44  134.10  9292519.0
# 2022-12-29  132.93  133.27  132.31  133.22  6585228.0
# 2022-12-28  131.85  133.41  131.01  132.46  8827738.0
# 2022-12-27  131.57  132.22  130.55  131.74  5410991.0
# 2022-12-23  130.58  131.44  129.64  131.28  5091905.0

# %%
df.tail()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2013-01-08  34.6350  34.7126  34.3020  34.7126  2.572222e+07
# 2013-01-07  34.4385  34.7038  34.3462  34.6429  3.205830e+07
# 2013-01-04  33.9100  34.6606  33.9011  34.6036  3.210123e+07
# 2013-01-03  34.1320  34.1379  33.7164  34.0023  3.175870e+07
# 2013-01-02  34.3177  34.3324  33.7341  34.0721  4.118124e+07

# %%
#  Date becomes column and are removable.
df=df.reset_index()
df.head()
# Out:
#         Date    Open    High     Low   Close     Volume
# 0 2022-12-30  132.81  134.33  132.44  134.10  9292519.0
# 1 2022-12-29  132.93  133.27  132.31  133.22  6585228.0
# 2 2022-12-28  131.85  133.41  131.01  132.46  8827738.0
# 3 2022-12-27  131.57  132.22  130.55  131.74  5410991.0
# 4 2022-12-23  130.58  131.44  129.64  131.28  5091905.0

# %% [markdown]
# # Information
#
# This code deletes "Date" column from the dataset as they are not useful in our plotting.

# %%
df=df.drop(['Date'],axis=1)
df.head()
# Out:
#      Open    High     Low   Close     Volume
# 0  132.81  134.33  132.44  134.10  9292519.0
# 1  132.93  133.27  132.31  133.22  6585228.0
# 2  131.85  133.41  131.01  132.46  8827738.0
# 3  131.57  132.22  130.55  131.74  5410991.0
# 4  130.58  131.44  129.64  131.28  5091905.0

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig=plt.figure(figsize=(10,6))
fig.patch.set_facecolor('#42A5F5')

ax=plt.axes()
ax.set_facecolor('#C7E1F4')

plt.plot(df.Close, '#FF8F00', label='Closing Price')

plt.legend()
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.xticks(rotation=45)

plt.grid(True,linestyle='--',color='#BDBDBD')
plt.tight_layout()
plt.show()

# %%
df
# Out:
#           Open      High       Low     Close        Volume
# 0     132.8100  134.3300  132.4400  134.1000  9.292519e+06
# 1     132.9300  133.2700  132.3100  133.2200  6.585228e+06
# 2     131.8500  133.4100  131.0100  132.4600  8.827738e+06
# 3     131.5700  132.2200  130.5500  131.7400  5.410991e+06
# 4     130.5800  131.4400  129.6400  131.2800  5.091905e+06
# ...        ...       ...       ...       ...           ...
# 2513   34.6350   34.7126   34.3020   34.7126  2.572222e+07
# 2514   34.4385   34.7038   34.3462   34.6429  3.205830e+07
# 2515   33.9100   34.6606   33.9011   34.6036  3.210123e+07
# 2516   34.1320   34.1379   33.7164   34.0023  3.175870e+07
# 2517   34.3177   34.3324   33.7341   34.0721  4.118124e+07
#
# [2518 rows x 5 columns]

# %%
# ma100 is created for finding the mean of the 100 values and displaying them.
# for that rolling() function is used.

ma100=df.Close.rolling(100).mean()
ma100
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2513    37.397394
# 2514    37.324762
# 2515    37.243809
# 2516    37.164133
# 2517    37.085725
# Name: Close, Length: 2518, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
fig.patch.set_facecolor('#42A5F5')

ax=plt.axes()
ax.set_facecolor('#C7E1F4')

plt.grid(True,linestyle='--',color='#BDBDBD')
plt.tight_layout()

plt.plot(df.Close, '#FF8F00', label='Closing Price')
plt.plot(ma100,'g--',label='Mean (100 val)') # this is the mean of 100 values

plt.legend()
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.show()

# %%
ma200=df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2513    39.338182
# 2514    39.302568
# 2515    39.264229
# 2516    39.222755
# 2517    39.181974
# Name: Close, Length: 2518, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

ma100=df.Close.rolling(100).mean()
ma100

fig=plt.figure(figsize=(12,6))
fig.patch.set_facecolor('#A59DDF')

ax=plt.axes()
ax.set_facecolor('#211970')

plt.grid(True,linestyle='--',color='#626784')
plt.xticks(rotation=45)

plt.plot(df.Close,'#A720C4',label='Closing Price')
plt.plot(ma100,'g',label='Mean (100 val)') # this is the mean of 100 values
plt.plot(ma200,'r',label='Mean (200 val)') # this is the mean of 200 values

plt.legend()
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
# Out:
# Text(0, 0.5, 'Closing Price (USD)')

# %%
df.shape
# Out:
# (2518, 5)

# %%
# splitting the data into training and testing
import pandas as pd

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print("Used data for training: ", data_training.shape)
print("Used data for testing: ", data_testing.shape)
# Out:
# Used data for training:  (1762, 1)
# Used data for testing:  (756, 1)

# %%
data_training.head()
# Out:
#     Close
# 0  134.10
# 1  133.22
# 2  132.46
# 3  131.74
# 4  131.28

# %%
data_testing.head()
# Out:
#         Close
# 1762  54.2504
# 1763  54.7072
# 1764  55.0983
# 1765  54.5364
# 1766  54.7162

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.73560221],
#        [0.72842635],
#        [0.72222902],
#        ...,
#        [0.06570804],
#        [0.07190048],
#        [0.07117148]])

# %%
import numpy as np

# The data is dependant on the previous result. (ma100) and (ma200)
# So, to calculate the next day value we train the following array.
# 100 days are x_train and 101 day is y_train and it goes on changing.

x_train = []
y_train = []


for i in range(100,data_training_array.shape[0]):
  x_train.append(data_training_array[i-100: i])
  y_train.append(data_training_array[i, 0])


x_train

# Now, converting x_train into numpy value, so that it can be provided to LSTM.
x_train,y_train = np.array(x_train), np.array(y_train)

# %%
# !pip install tensorflow
# !pip install tensorflow-addons==0.17.1

# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting tensorflow-addons==0.17.1
#   Using cached tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (24.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (2.13.3)
# Using cached tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Installing collected packages: tensorflow-addons
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.23.0
#     Uninstalling tensorflow-addons-0.23.0:
#       Successfully uninstalled tensorflow-addons-0.23.0
# Successfully installed tensorflow-addons-0.17.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Collecting tensorflow-addons
#   Using cached tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Using cached tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
# Installing collected packages: tensorflow-addons
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.17.1
#     Uninstalling tensorflow-addons-0.17.1:
#       Successfully uninstalled tensorflow-addons-0.17.1
# Successfully installed tensorflow-addons-0.23.0

# %%
import tensorflow as tf

# Use the recommended import path for LSTM
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
# Use the recommended import path for LSTM
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import Orthogonal

# ... rest of your code ...
import tensorflow as tf


model = tf.keras.Sequential()
model.add(LSTM(units=50,
               activation ='relu',
               return_sequences = True,
               input_shape=(x_train.shape[1],1),
                recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.2))


# Second Layer
model.add(LSTM(units=60,
               activation ='relu',
               return_sequences = True,
               recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.3))



model.add(LSTM(units=80,
               activation ='relu',
               return_sequences = True,
               recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.4))



model.add(LSTM(units=120,
               activation ='relu',
               recurrent_initializer="orthogonal"
               )
)
model.add(Dropout(0.5))



# Dense Layer - to connect all the layers
# model.add(Dense(units=1))
model.add(tf.keras.layers.Dense(units=1, kernel_initializer=Orthogonal(gain=1.0, seed=None)))

# Set Optimizer
opt = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                        │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_9 (LSTM)                        │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_10 (LSTM)                       │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# !pip install tensorflow-addons==0.17.1

# !pip install --upgrade tensorflow
# !pip install --upgrade tensorflow-addons
# Out:
# Collecting tensorflow-addons==0.17.1
#   Using cached tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (24.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons==0.17.1) (2.13.3)
# Using cached tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Installing collected packages: tensorflow-addons
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.23.0
#     Uninstalling tensorflow-addons-0.23.0:
#       Successfully uninstalled tensorflow-addons-0.23.0
# Successfully installed tensorflow-addons-0.17.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Collecting tensorflow-addons
#   Using cached tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)
# Using cached tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
# Installing collected packages: tensorflow-addons
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.17.1
#     Uninstalling tensorflow-addons-0.17.1:
#       Successfully uninstalled tensorflow-addons-0.17.1
# Successfully installed tensorflow-addons-0.23.0

# %%
# Try importing AbstractRNNCell from tensorflow.python.keras.layers instead

from tensorflow.python.keras.layers import AbstractRNNCell

# Remove the incorrect import and keep the original correct one
# from tensorflow.python.keras.layers import Dense, Dropout, LSTM, BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization # This line was already in a previous cell, keep it
from tensorflow.python.keras.callbacks import TensorBoard
from tensorflow.python.keras.callbacks import ModelCheckpoint

from tensorflow.python.keras.initializers import Orthogonal
from tensorflow.python.keras.metrics import MeanSquaredError, MeanAbsoluteError

model.compile(optimizer=opt,
              loss='mean_squared_error',  # Retain MSE for regression
              metrics=['accuracy',  # Include accuracy for reference (optional)
                       MeanSquaredError(),
                       MeanAbsoluteError()])

model.fit(x_train,y_train,epochs=150)
# Out:
# Epoch 1/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 39s 395ms/step - accuracy: 1.9423e-04 - loss: 0.1614 - mean_absolute_error: 0.3749 - mean_squared_error: 0.2033
# Epoch 2/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 0.0024 - loss: 0.0326 - mean_absolute_error: 0.2399 - mean_squared_error: 0.0969
# Epoch 3/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 310ms/step - accuracy: 0.0015 - loss: 0.0103 - mean_absolute_error: 0.1765 - mean_squared_error: 0.0609
# Epoch 4/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 342ms/step - accuracy: 9.1547e-04 - loss: 0.0085 - mean_absolute_error: 0.1435 - mean_squared_error: 0.0449
# Epoch 5/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 0.0013 - loss: 0.0079 - mean_absolute_error: 0.1249 - mean_squared_error: 0.0362
# Epoch 6/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 314ms/step - accuracy: 5.5040e-04 - loss: 0.0081 - mean_absolute_error: 0.1132 - mean_squared_error: 0.0308
# Epoch 7/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - accuracy: 0.0035 - loss: 0.0068 - mean_absolute_error: 0.1051 - mean_squared_error: 0.0271
# Epoch 8/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 9.9559e-04 - loss: 0.0074 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0244
# Epoch 9/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 319ms/step - accuracy: 0.0011 - loss: 0.0064 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0223
# Epoch 10/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step - accuracy: 6.6313e-04 - loss: 0.0064 - mean_absolute_error: 0.0904 - mean_squared_error: 0.0206
# Epoch 11/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 317ms/step - accuracy: 0.0029 - loss: 0.0062 - mean_absolute_error: 0.0872 - mean_squared_error: 0.0192
# Epoch 12/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 311ms/step - accuracy: 0.0022 - loss: 0.0069 - mean_absolute_error: 0.0845 - mean_squared_error: 0.0180
# Epoch 13/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 313ms/step - accuracy: 0.0016 - loss: 0.0061 - mean_absolute_error: 0.0822 - mean_squared_error: 0.0171
# Epoch 14/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 8.5332e-04 - loss: 0.0058 - mean_absolute_error: 0.0802 - mean_squared_error: 0.0162
# Epoch 15/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 334ms/step - accuracy: 0.0018 - loss: 0.0055 - mean_absolute_error: 0.0785 - mean_squared_error: 0.0155
# Epoch 16/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 311ms/step - accuracy: 0.0014 - loss: 0.0046 - mean_absolute_error: 0.0768 - mean_squared_error: 0.0149
# Epoch 17/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 305ms/step - accuracy: 2.8997e-04 - loss: 0.0047 - mean_absolute_error: 0.0752 - mean_squared_error: 0.0142
# Epoch 18/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 0.0018 - loss: 0.0051 - mean_absolute_error: 0.0739 - mean_squared_error: 0.0137
# Epoch 19/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - accuracy: 8.0797e-05 - loss: 0.0049 - mean_absolute_error: 0.0726 - mean_squared_error: 0.0133
# Epoch 20/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step - accuracy: 0.0024 - loss: 0.0050 - mean_absolute_error: 0.0715 - mean_squared_error: 0.0128
# Epoch 21/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 316ms/step - accuracy: 2.2850e-04 - loss: 0.0047 - mean_absolute_error: 0.0704 - mean_squared_error: 0.0124
# Epoch 22/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 332ms/step - accuracy: 6.1975e-04 - loss: 0.0042 - mean_absolute_error: 0.0694 - mean_squared_error: 0.0121
# Epoch 23/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 312ms/step - accuracy: 0.0022 - loss: 0.0046 - mean_absolute_error: 0.0684 - mean_squared_error: 0.0117
# Epoch 24/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 300ms/step - accuracy: 7.2944e-04 - loss: 0.0040 - mean_absolute_error: 0.0675 - mean_squared_error: 0.0114
# Epoch 25/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 314ms/step - accuracy: 0.0022 - loss: 0.0047 - mean_absolute_error: 0.0667 - mean_squared_error: 0.0111
# Epoch 26/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 311ms/step - accuracy: 4.6254e-04 - loss: 0.0044 - mean_absolute_error: 0.0659 - mean_squared_error: 0.0109
# Epoch 27/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 315ms/step - accuracy: 0.0018 - loss: 0.0041 - mean_absolute_error: 0.0652 - mean_squared_error: 0.0106
# Epoch 28/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - accuracy: 7.3016e-04 - loss: 0.0035 - mean_absolute_error: 0.0646 - mean_squared_error: 0.0104
# Epoch 29/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 314ms/step - accuracy: 9.0971e-04 - loss: 0.0039 - mean_absolute_error: 0.0639 - mean_squared_error: 0.0101
# Epoch 30/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 324ms/step - accuracy: 0.0022 - loss: 0.0041 - mean_absolute_error: 0.0633 - mean_squared_error: 0.0099
# Epoch 31/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 0.0017 - loss: 0.0037 - mean_absolute_error: 0.0627 - mean_squared_error: 0.0097
# Epoch 32/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 314ms/step - accuracy: 5.7172e-04 - loss: 0.0035 - mean_absolute_error: 0.0621 - mean_squared_error: 0.0095
# Epoch 33/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.0013 - loss: 0.0036 - mean_absolute_error: 0.0616 - mean_squared_error: 0.0094
# Epoch 34/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 316ms/step - accuracy: 0.0012 - loss: 0.0034 - mean_absolute_error: 0.0610 - mean_squared_error: 0.0092
# Epoch 35/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 316ms/step - accuracy: 2.1694e-04 - loss: 0.0038 - mean_absolute_error: 0.0605 - mean_squared_error: 0.0090
# Epoch 36/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 309ms/step - accuracy: 9.3885e-04 - loss: 0.0033 - mean_absolute_error: 0.0600 - mean_squared_error: 0.0089
# Epoch 37/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 331ms/step - accuracy: 0.0014 - loss: 0.0031 - mean_absolute_error: 0.0595 - mean_squared_error: 0.0087
# Epoch 38/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 8.9736e-04 - loss: 0.0032 - mean_absolute_error: 0.0590 - mean_squared_error: 0.0086
# Epoch 39/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - accuracy: 1.0415e-04 - loss: 0.0031 - mean_absolute_error: 0.0585 - mean_squared_error: 0.0084
# Epoch 40/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 329ms/step - accuracy: 0.0017 - loss: 0.0034 - mean_absolute_error: 0.0581 - mean_squared_error: 0.0083
# Epoch 41/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 321ms/step - accuracy: 0.0016 - loss: 0.0035 - mean_absolute_error: 0.0577 - mean_squared_error: 0.0082
# Epoch 42/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 323ms/step - accuracy: 0.0032 - loss: 0.0032 - mean_absolute_error: 0.0574 - mean_squared_error: 0.0081
# Epoch 43/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 304ms/step - accuracy: 0.0014 - loss: 0.0039 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0080
# Epoch 44/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 18s 340ms/step - accuracy: 6.2568e-04 - loss: 0.0028 - mean_absolute_error: 0.0567 - mean_squared_error: 0.0079
# Epoch 45/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 326ms/step - accuracy: 6.7819e-04 - loss: 0.0028 - mean_absolute_error: 0.0563 - mean_squared_error: 0.0077
# Epoch 46/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 307ms/step - accuracy: 4.8835e-04 - loss: 0.0031 - mean_absolute_error: 0.0559 - mean_squared_error: 0.0076
# Epoch 47/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 319ms/step - accuracy: 1.5490e-04 - loss: 0.0031 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0075
# Epoch 48/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 18s 340ms/step - accuracy: 0.0010 - loss: 0.0029 - mean_absolute_error: 0.0553 - mean_squared_error: 0.0074
# Epoch 49/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 306ms/step - accuracy: 0.0023 - loss: 0.0030 - mean_absolute_error: 0.0550 - mean_squared_error: 0.0074
# Epoch 50/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 316ms/step - accuracy: 0.0013 - loss: 0.0027 - mean_absolute_error: 0.0546 - mean_squared_error: 0.0073
# Epoch 51/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 334ms/step - accuracy: 5.3592e-04 - loss: 0.0028 - mean_absolute_error: 0.0543 - mean_squared_error: 0.0072
# Epoch 52/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 319ms/step - accuracy: 4.5983e-04 - loss: 0.0029 - mean_absolute_error: 0.0540 - mean_squared_error: 0.0071
# Epoch 53/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 312ms/step - accuracy: 0.0012 - loss: 0.0031 - mean_absolute_error: 0.0537 - mean_squared_error: 0.0070
# Epoch 54/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 313ms/step - accuracy: 5.8130e-04 - loss: 0.0026 - mean_absolute_error: 0.0534 - mean_squared_error: 0.0069
# Epoch 55/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 328ms/step - accuracy: 0.0015 - loss: 0.0029 - mean_absolute_error: 0.0531 - mean_squared_error: 0.0068
# Epoch 56/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 306ms/step - accuracy: 0.0017 - loss: 0.0024 - mean_absolute_error: 0.0528 - mean_squared_error: 0.0068
# Epoch 57/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - accuracy: 0.0010 - loss: 0.0028 - mean_absolute_error: 0.0525 - mean_squared_error: 0.0067
# Epoch 58/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 341ms/step - accuracy: 2.0182e-04 - loss: 0.0027 - mean_absolute_error: 0.0522 - mean_squared_error: 0.0066
# Epoch 59/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 313ms/step - accuracy: 0.0013 - loss: 0.0024 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0066
# Epoch 60/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 313ms/step - accuracy: 0.0014 - loss: 0.0023 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0065
# Epoch 61/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - accuracy: 6.8410e-04 - loss: 0.0027 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0064
# Epoch 62/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - accuracy: 0.0018 - loss: 0.0024 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0064
# Epoch 63/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 329ms/step - accuracy: 0.0016 - loss: 0.0030 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0063
# Epoch 64/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 339ms/step - accuracy: 0.0016 - loss: 0.0025 - mean_absolute_error: 0.0508 - mean_squared_error: 0.0062
# Epoch 65/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 302ms/step - accuracy: 7.9662e-04 - loss: 0.0028 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0062
# Epoch 66/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 328ms/step - accuracy: 2.8161e-04 - loss: 0.0023 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0061
# Epoch 67/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 2.9267e-04 - loss: 0.0026 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0061
# Epoch 68/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 318ms/step - accuracy: 5.6578e-04 - loss: 0.0024 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0060
# Epoch 69/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 305ms/step - accuracy: 7.2066e-04 - loss: 0.0022 - mean_absolute_error: 0.0498 - mean_squared_error: 0.0060
# Epoch 70/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.0022 - loss: 0.0022 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0059
# Epoch 71/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 341ms/step - accuracy: 6.6281e-04 - loss: 0.0024 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0059
# Epoch 72/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 313ms/step - accuracy: 8.0502e-04 - loss: 0.0025 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0058
# Epoch 73/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 305ms/step - accuracy: 0.0020 - loss: 0.0021 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0058
# Epoch 74/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 326ms/step - accuracy: 8.7011e-04 - loss: 0.0025 - mean_absolute_error: 0.0488 - mean_squared_error: 0.0057
# Epoch 75/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 305ms/step - accuracy: 2.3721e-04 - loss: 0.0025 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0057
# Epoch 76/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 328ms/step - accuracy: 8.1193e-04 - loss: 0.0026 - mean_absolute_error: 0.0485 - mean_squared_error: 0.0056
# Epoch 77/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 314ms/step - accuracy: 0.0012 - loss: 0.0025 - mean_absolute_error: 0.0483 - mean_squared_error: 0.0056
# Epoch 78/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 18s 340ms/step - accuracy: 3.4570e-04 - loss: 0.0025 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0056
# Epoch 79/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 8.8240e-04 - loss: 0.0022 - mean_absolute_error: 0.0480 - mean_squared_error: 0.0055
# Epoch 80/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 308ms/step - accuracy: 0.0013 - loss: 0.0023 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0055
# Epoch 81/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 303ms/step - accuracy: 0.0015 - loss: 0.0023 - mean_absolute_error: 0.0477 - mean_squared_error: 0.0054
# Epoch 82/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 306ms/step - accuracy: 2.7715e-04 - loss: 0.0025 - mean_absolute_error: 0.0475 - mean_squared_error: 0.0054
# Epoch 83/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 316ms/step - accuracy: 0.0014 - loss: 0.0026 - mean_absolute_error: 0.0474 - mean_squared_error: 0.0054
# Epoch 84/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 347ms/step - accuracy: 9.9438e-04 - loss: 0.0023 - mean_absolute_error: 0.0472 - mean_squared_error: 0.0053
# Epoch 85/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 302ms/step - accuracy: 0.0018 - loss: 0.0025 - mean_absolute_error: 0.0471 - mean_squared_error: 0.0053
# Epoch 86/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 309ms/step - accuracy: 2.3245e-04 - loss: 0.0022 - mean_absolute_error: 0.0470 - mean_squared_error: 0.0053
# Epoch 87/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 336ms/step - accuracy: 0.0011 - loss: 0.0023 - mean_absolute_error: 0.0468 - mean_squared_error: 0.0052
# Epoch 88/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 316ms/step - accuracy: 9.7162e-04 - loss: 0.0024 - mean_absolute_error: 0.0467 - mean_squared_error: 0.0052
# Epoch 89/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 316ms/step - accuracy: 0.0031 - loss: 0.0021 - mean_absolute_error: 0.0466 - mean_squared_error: 0.0052
# Epoch 90/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 330ms/step - accuracy: 0.0013 - loss: 0.0023 - mean_absolute_error: 0.0464 - mean_squared_error: 0.0051
# Epoch 91/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 3.4018e-04 - loss: 0.0024 - mean_absolute_error: 0.0463 - mean_squared_error: 0.0051
# Epoch 92/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 323ms/step - accuracy: 0.0018 - loss: 0.0022 - mean_absolute_error: 0.0462 - mean_squared_error: 0.0051
# Epoch 93/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 300ms/step - accuracy: 0.0017 - loss: 0.0021 - mean_absolute_error: 0.0460 - mean_squared_error: 0.0050
# Epoch 94/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 338ms/step - accuracy: 9.6201e-04 - loss: 0.0021 - mean_absolute_error: 0.0459 - mean_squared_error: 0.0050
# Epoch 95/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 307ms/step - accuracy: 0.0019 - loss: 0.0023 - mean_absolute_error: 0.0458 - mean_squared_error: 0.0050
# Epoch 96/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 330ms/step - accuracy: 4.5537e-04 - loss: 0.0024 - mean_absolute_error: 0.0457 - mean_squared_error: 0.0049
# Epoch 97/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 309ms/step - accuracy: 9.5266e-04 - loss: 0.0024 - mean_absolute_error: 0.0456 - mean_squared_error: 0.0049
# Epoch 98/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 328ms/step - accuracy: 3.2142e-04 - loss: 0.0023 - mean_absolute_error: 0.0455 - mean_squared_error: 0.0049
# Epoch 99/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 300ms/step - accuracy: 0.0028 - loss: 0.0023 - mean_absolute_error: 0.0454 - mean_squared_error: 0.0049
# Epoch 100/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - accuracy: 0.0013 - loss: 0.0021 - mean_absolute_error: 0.0452 - mean_squared_error: 0.0048
# Epoch 101/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 302ms/step - accuracy: 0.0025 - loss: 0.0020 - mean_absolute_error: 0.0451 - mean_squared_error: 0.0048
# Epoch 102/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 328ms/step - accuracy: 2.4480e-04 - loss: 0.0025 - mean_absolute_error: 0.0450 - mean_squared_error: 0.0048
# Epoch 103/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 298ms/step - accuracy: 0.0019 - loss: 0.0023 - mean_absolute_error: 0.0449 - mean_squared_error: 0.0048
# Epoch 104/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 15s 296ms/step - accuracy: 5.1880e-04 - loss: 0.0021 - mean_absolute_error: 0.0448 - mean_squared_error: 0.0047
# Epoch 105/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 301ms/step - accuracy: 5.7363e-04 - loss: 0.0023 - mean_absolute_error: 0.0447 - mean_squared_error: 0.0047
# Epoch 106/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 301ms/step - accuracy: 0.0014 - loss: 0.0022 - mean_absolute_error: 0.0446 - mean_squared_error: 0.0047
# Epoch 107/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 8.8246e-04 - loss: 0.0021 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0047
# Epoch 108/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 5.8130e-04 - loss: 0.0022 - mean_absolute_error: 0.0444 - mean_squared_error: 0.0046
# Epoch 109/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 306ms/step - accuracy: 2.7223e-04 - loss: 0.0022 - mean_absolute_error: 0.0443 - mean_squared_error: 0.0046
# Epoch 110/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 299ms/step - accuracy: 0.0014 - loss: 0.0023 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0046
# Epoch 111/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 311ms/step - accuracy: 7.6153e-04 - loss: 0.0022 - mean_absolute_error: 0.0442 - mean_squared_error: 0.0046
# Epoch 112/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 320ms/step - accuracy: 2.2850e-04 - loss: 0.0019 - mean_absolute_error: 0.0441 - mean_squared_error: 0.0045
# Epoch 113/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 304ms/step - accuracy: 6.6281e-04 - loss: 0.0022 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0045
# Epoch 114/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 305ms/step - accuracy: 5.5067e-04 - loss: 0.0022 - mean_absolute_error: 0.0439 - mean_squared_error: 0.0045
# Epoch 115/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 310ms/step - accuracy: 0.0023 - loss: 0.0020 - mean_absolute_error: 0.0438 - mean_squared_error: 0.0045
# Epoch 116/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - accuracy: 0.0016 - loss: 0.0021 - mean_absolute_error: 0.0437 - mean_squared_error: 0.0045
# Epoch 117/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 311ms/step - accuracy: 4.3802e-04 - loss: 0.0021 - mean_absolute_error: 0.0436 - mean_squared_error: 0.0044
# Epoch 118/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 307ms/step - accuracy: 0.0011 - loss: 0.0020 - mean_absolute_error: 0.0435 - mean_squared_error: 0.0044
# Epoch 119/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 302ms/step - accuracy: 5.1832e-04 - loss: 0.0021 - mean_absolute_error: 0.0434 - mean_squared_error: 0.0044
# Epoch 120/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 299ms/step - accuracy: 0.0013 - loss: 0.0021 - mean_absolute_error: 0.0433 - mean_squared_error: 0.0044
# Epoch 121/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 300ms/step - accuracy: 4.8482e-04 - loss: 0.0020 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0044
# Epoch 122/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 305ms/step - accuracy: 2.3475e-04 - loss: 0.0019 - mean_absolute_error: 0.0432 - mean_squared_error: 0.0043
# Epoch 123/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 299ms/step - accuracy: 0.0012 - loss: 0.0020 - mean_absolute_error: 0.0431 - mean_squared_error: 0.0043
# Epoch 124/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 305ms/step - accuracy: 1.1618e-04 - loss: 0.0022 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0043
# Epoch 125/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 305ms/step - accuracy: 7.2066e-04 - loss: 0.0022 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0043
# Epoch 126/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 311ms/step - accuracy: 8.6837e-04 - loss: 0.0022 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0043
# Epoch 127/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 318ms/step - accuracy: 2.5883e-04 - loss: 0.0022 - mean_absolute_error: 0.0428 - mean_squared_error: 0.0042
# Epoch 128/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 340ms/step - accuracy: 0.0011 - loss: 0.0018 - mean_absolute_error: 0.0427 - mean_squared_error: 0.0042
# Epoch 129/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 19s 309ms/step - accuracy: 1.9605e-04 - loss: 0.0023 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0042
# Epoch 130/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.0015 - loss: 0.0021 - mean_absolute_error: 0.0426 - mean_squared_error: 0.0042
# Epoch 131/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 308ms/step - accuracy: 3.5861e-04 - loss: 0.0019 - mean_absolute_error: 0.0425 - mean_squared_error: 0.0042
# Epoch 132/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.0013 - loss: 0.0020 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0042
# Epoch 133/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 319ms/step - accuracy: 0.0010 - loss: 0.0020 - mean_absolute_error: 0.0424 - mean_squared_error: 0.0041
# Epoch 134/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 309ms/step - accuracy: 5.5565e-04 - loss: 0.0021 - mean_absolute_error: 0.0423 - mean_squared_error: 0.0041
# Epoch 135/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.0021 - loss: 0.0021 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0041
# Epoch 136/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 0.0016 - loss: 0.0020 - mean_absolute_error: 0.0422 - mean_squared_error: 0.0041
# Epoch 137/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 300ms/step - accuracy: 5.4518e-04 - loss: 0.0020 - mean_absolute_error: 0.0421 - mean_squared_error: 0.0041
# Epoch 138/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 308ms/step - accuracy: 0.0016 - loss: 0.0021 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0041
# Epoch 139/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 294ms/step - accuracy: 0.0026 - loss: 0.0023 - mean_absolute_error: 0.0420 - mean_squared_error: 0.0041
# Epoch 140/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 305ms/step - accuracy: 0.0022 - loss: 0.0021 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0040
# Epoch 141/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 303ms/step - accuracy: 5.0145e-04 - loss: 0.0019 - mean_absolute_error: 0.0419 - mean_squared_error: 0.0040
# Epoch 142/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 16s 310ms/step - accuracy: 0.0025 - loss: 0.0023 - mean_absolute_error: 0.0418 - mean_squared_error: 0.0040
# Epoch 143/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 302ms/step - accuracy: 0.0011 - loss: 0.0020 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0040
# Epoch 144/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 21s 304ms/step - accuracy: 6.6886e-04 - loss: 0.0024 - mean_absolute_error: 0.0417 - mean_squared_error: 0.0040
# Epoch 145/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 333ms/step - accuracy: 0.0015 - loss: 0.0018 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0040
# Epoch 146/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 321ms/step - accuracy: 0.0012 - loss: 0.0020 - mean_absolute_error: 0.0416 - mean_squared_error: 0.0040
# Epoch 147/150
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 20s 318ms/step - accuracy: 0.0016 - loss: 0.0021 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0040
# Epoch 148/150
#  7/52 ━━━━━━━━━━━━━━━━━━━━ 13s 302ms/step - accuracy: 0.0000e+00 - loss: 0.0022 - mean_absolute_error: 0.0415 - mean_squared_error: 0.0039

# %%
model.save('keras_model_last.h5')

# %%
data_testing.head()

# %%
data_training.head()

# %%
# We need previous 100 days data and we need to comapre and append the list.
past_100_days = data_training.tail(100)
final_df = pd.concat([past_100_days, data_testing], ignore_index=True)

# %%
final_df.head()

# %%
input_data = scaler.fit_transform(final_df)
input_data

# %%
input_data.shape

# %%
x_test = []
y_test = []

for i in range(100,input_data.shape[0]):
  x_test.append(input_data[i-100: i])
  y_test.append(input_data[i, 0])

# %%
x_test,y_test= np.array(x_test),np.array(y_test)

print(x_test.shape)
print(y_test.shape)

# %%
# Making Predictions

y_predicted = model.predict(x_test)

# %%
y_predicted.shape

# %%
y_test

# %%
y_predicted

# %%
scaler.scale_

# %%
scale_factor=1/0.02105662
y_predicted= y_predicted* scale_factor
y_test = y_test * scale_factor

# %%
y_predicted

# %%
fig=plt.figure(figsize=(12,6))
fig.patch.set_facecolor('#A59DDF')

ax=plt.axes()
ax.set_facecolor('#211970')

plt.grid(True,linestyle='--',color='#626784')
plt.plot(y_test,'#A720C4',label="Original price")
plt.plot(y_predicted,'#DFB729',label="Predicted price")

plt.xlabel('Time')
plt.ylabel('Stock Price($)')
plt.legend()
plt.show()
